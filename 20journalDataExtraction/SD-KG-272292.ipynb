# %%
# Advanced Engineering Informatics
idNo = '272292'

# %%
import requests
from bs4 import BeautifulSoup
from pandas.io.html import read_html
import pandas as pd
import json
import csv

# %%
df = pd.DataFrame()
df.to_csv('blankFile.csv')

columnNames = ['searchTerm1','searchTerm2','url','Title']

df = pd.read_csv("blankFile.csv", names= columnNames , header = None)
df = df.iloc[1:]

for i in range(20):
    section = "section" + str(i)
    sectionData = "sectionData" + str(i)
    df[section] = ''
    df[sectionData] = ''

df
# Out:
# Empty DataFrame
# Columns: [searchTerm1, searchTerm2, url, Title, section0, sectionData0, section1, sectionData1, section2, sectionData2, section3, sectionData3, section4, sectionData4, section5, sectionData5, section6, sectionData6, section7, sectionData7, section8, sectionData8, section9, sectionData9, section10, sectionData10, section11, sectionData11, section12, sectionData12, section13, sectionData13, section14, sectionData14, section15, sectionData15, section16, sectionData16, section17, sectionData17, section18, sectionData18, section19, sectionData19]
# Index: []
#
# [0 rows x 44 columns]

# %%
df
# Out:
# Empty DataFrame
# Columns: [searchTerm1, searchTerm2, url, Title, section0, sectionData0, section1, sectionData1, section2, sectionData2, section3, sectionData3, section4, sectionData4, section5, sectionData5, section6, sectionData6, section7, sectionData7, section8, sectionData8, section9, sectionData9, section10, sectionData10, section11, sectionData11, section12, sectionData12, section13, sectionData13, section14, sectionData14, section15, sectionData15, section16, sectionData16, section17, sectionData17, section18, sectionData18, section19, sectionData19]
# Index: []
#
# [0 rows x 44 columns]

# %%
# searchTerm1 = ['Building Information Modelling']
# searchTerm2 = ['Green Buildings']

# searchTerm1 = ['BIM']
# searchTerm2 = ['Sustainability']

tc = 0

searchTerm1 = ['BIM' , 'Building Information Modelling','Building information model','6D BIM', 'Digital construction','Smart construction','Digital engineering']
searchTerm2 = ['Green Building' , 'Green Buildings','Sustainable building','Sustainable buildings','Environmentally friendly design' , 'Sustainability' , 'Sustainable development' , 'Energy','Water' ,'Waste' , 'Thermal comfort','Electricity' ,'Solar','Wind power' , 'Green infrastructure','Life cycle assessment']

counter = 0
programSearchTerms1 = []
programSearchTerms2 = []

for term2 in searchTerm2:
    text2 = ""
    terms2 = term2.split(' ')
    for t2 in terms2:
        text2 = text2 + t2 + "%20"

    fileIndex = text2.rfind("%20")
    te = text2[:fileIndex]
    programSearchTerms2.append(te)

print(programSearchTerms2)

for term1 in searchTerm1:
    text1 = ""
    terms1 = term1.split(' ')
    for t2 in terms1:
        text1 = text1 + t2 + "%20"

    fileIndex = text1.rfind("%20")
    te = text1[:fileIndex]
    programSearchTerms1.append(te)

print(programSearchTerms1)
# Out:
# ['Green%20Building', 'Green%20Buildings', 'Sustainable%20building', 'Sustainable%20buildings', 'Environmentally%20friendly%20design', 'Sustainability', 'Sustainable%20development', 'Energy', 'Water', 'Waste', 'Thermal%20comfort', 'Electricity', 'Solar', 'Wind%20power', 'Green%20infrastructure', 'Life%20cycle%20assessment']
# ['BIM', 'Building%20Information%20Modelling', 'Building%20information%20model', '6D%20BIM', 'Digital%20construction', 'Smart%20construction', 'Digital%20engineering']

# %%
def getData(link):
    browser = webdriver.Safari()
    browser.get(link)
    respData = browser.page_source
    browser.quit()
    parsed_html = BeautifulSoup(respData)
    
    title = parsed_html.find('span',{'class':'title-text'}).text
    print("Title: ",title)
    df.loc[row,'url'] = link
    df.loc[row,'Title'] = title
    
    absResults = parsed_html.find('div',{'class':'abstract author'})
    
    if absResults is not None:
        try:            
            df.loc[row,'section0'] = absResults.find('h2').text
            df.loc[row,'sectionData0'] = absResults.find('div').text
        except:
            df.loc[row,'section0'] = "None"
            df.loc[row,'sectionData0'] = "None"
    else:
        df.loc[row,'section0'] = "None"
        df.loc[row,'sectionData0'] = "None"

        
    sections = parsed_html.find('div',{'class':'Body u-font-serif'})
    if sections is not None:        
        sections = sections.find_next('div')
        count = 1 
        for section in sections:
            if section is not None: 
                sectionNo = 'section' + str(count)
                sectionData = 'sectionData' + str(count)
                try:
                    df.loc[row,sectionNo] = section.find('h2',{'class':'u-h3 u-margin-l-top u-margin-xs-bottom'}).text
                except:
                    df.loc[row,sectionNo] = "Some issue"
                    
                data = ''
                for para in section.findAll('p'):
                    data = data + para.text
                df.loc[row,sectionData] = data
            else:
                df.loc[row,sectionNo] = "None"
            count = count + 1

# %%
from bs4 import BeautifulSoup
from selenium import webdriver

# %%
baseUrl = 'https://www.sciencedirect.com/search/api?tak=%22'

querySet = []
row = 0
for item1 in programSearchTerms1:
    for item2 in programSearchTerms2:
        sq = 'https://www.sciencedirect.com/search?qs=%22' + item1 + '%22%20%2B%20%22' + item2 + '%22'
        print("base query: ",sq)
        query = baseUrl + item1 +"%22%20%2B%20%22"+ item2+"%22&show=25&publicationTitles=" + idNo + "&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com"
        
        # Call webdriver         
        browser = webdriver.Safari()
        browser.get(query)
        respData = browser.page_source
        browser.quit()

        # Clear html         
        respData = respData.replace('<html><head></head><body><pre style="word-wrap: break-word; white-space: pre-wrap;">',"")
        respData = respData.replace('</pre></body></html>',"")
        
        py_dic = json.loads(respData)
        
        # Finding the number of pages in the selected journals.         
        for key in py_dic:
            if key == 'resultsFound':
                pageResults = py_dic[key]
        print("pageResults: ",pageResults)                
                                
        if pageResults > 25:
            page = pageResults // 25
            lastPage = pageResults % 25
            if lastPage > 0:
                page = page + 1
        else:
            page = 1
        print("page: ",page)

        #         for p in range(2):        
        for p in range(page):
            print("In page: ",p)
            if p == 0:
                query = baseUrl + item1 +"%22%20%2B%20%22"+ item2+"%22&show=25&publicationTitles=" + idNo + "&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com"
            else:
                offset = '&offset='+str(p*25)
                query = baseUrl + item1 +"%22%20%2B%20%22"+ item2+"%22&show=25&publicationTitles=" + idNo + "&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com"
                
            print("search query: ",query)  
                
            # Call webdriver         
            browser = webdriver.Safari()
            browser.get(query)
            respData = browser.page_source
            browser.quit()
            # Load Json Data 

            respData = respData.replace('<html><head></head><body><pre style="word-wrap: break-word; white-space: pre-wrap;">',"")
            respData = respData.replace('</pre></body></html>',"")

            py_dic = json.loads(respData)                
            # Quit the browser 
            links = []
            for key in py_dic:
                if key == 'searchResults':
                    for searchR in py_dic[key]:
                        for search in searchR:
                            if search == 'pdf':
                                for linkR in searchR[search]:
                                    if linkR == 'getAccessLink':
                                        baseLink = 'https://www.sciencedirect.com/'
                                        link = baseLink +searchR[search][linkR]
                                        print('Reading result: ',row)
                                        df.loc[row,'searchTerm1'] = item1
                                        df.loc[row,'searchTerm2'] = item2
                                        getData(link)                                    
                                        row = row + 1
# Out:
# base query:  https://www.sciencedirect.com/search?qs=%22BIM%22%20%2B%20%22Green%20Building%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22BIM%22%20%2B%20%22Green%20Building%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22BIM%22%20%2B%20%22Green%20Buildings%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22BIM%22%20%2B%20%22Green%20Buildings%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22BIM%22%20%2B%20%22Sustainable%20building%22
# pageResults:  1
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22BIM%22%20%2B%20%22Sustainable%20building%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# Reading result:  0
# Title:  Systems modelling for sustainable building design
# base query:  https://www.sciencedirect.com/search?qs=%22BIM%22%20%2B%20%22Sustainable%20buildings%22
# pageResults:  1
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22BIM%22%20%2B%20%22Sustainable%20buildings%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# Reading result:  1
# Title:  Systems modelling for sustainable building design
# base query:  https://www.sciencedirect.com/search?qs=%22BIM%22%20%2B%20%22Environmentally%20friendly%20design%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22BIM%22%20%2B%20%22Environmentally%20friendly%20design%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22BIM%22%20%2B%20%22Sustainability%22
# pageResults:  5
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22BIM%22%20%2B%20%22Sustainability%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# Reading result:  2
# Title:  BIM extension for the sustainability appraisal of conceptual steel design
# Reading result:  3
# Title:  Systems modelling for sustainable building design
# Reading result:  4
# Title:  Digital buildings – Challenges and opportunities
# Reading result:  5
# Title:  A cloud approach to unified lifecycle data management in architecture, engineering, construction and facilities management: Integrating BIMs and SNS
# Reading result:  6
# Title:  Methods for the Automated Assignment and Comparison of Building Damage Geometries
# base query:  https://www.sciencedirect.com/search?qs=%22BIM%22%20%2B%20%22Sustainable%20development%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22BIM%22%20%2B%20%22Sustainable%20development%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22BIM%22%20%2B%20%22Energy%22
# pageResults:  11
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22BIM%22%20%2B%20%22Energy%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# Reading result:  7
# Title:  BIM-enabled facilities operation and maintenance: A review
# Reading result:  8
# Title:  BIM-based investigation of total energy consumption in delivering building products
# Reading result:  9
# Title:  Quick energy prediction and comparison of options at the early design stage
# Reading result:  10
# Title:  BIMification: How to create and use BIM for retrofitting
# Reading result:  11
# Title:  Semantic information alignment of BIMs to computer-interpretable regulations using ontologies and deep learning
# Reading result:  12
# Title:  Information requirements for multi-level-of-development BIM using sensitivity analysis for energy performance
# Reading result:  13
# Title:  General system architecture for BIM: An integrated approach for design and analysis
# Reading result:  14
# Title:  Self-corrective knowledge-based hybrid tracking system using BIM and multimodal sensors
# Reading result:  15
# Title:  A meta-model approach for formal specification and consistent management of multi-LOD building models
# Reading result:  16
# Title:  Systems modelling for sustainable building design
# Reading result:  17
# Title:  3D as-is building energy modeling and diagnostics: A review of the state-of-the-art
# base query:  https://www.sciencedirect.com/search?qs=%22BIM%22%20%2B%20%22Water%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22BIM%22%20%2B%20%22Water%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22BIM%22%20%2B%20%22Waste%22
# pageResults:  1
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22BIM%22%20%2B%20%22Waste%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# Reading result:  18
# Title:  Automatic design and planning of scaffolding systems using building information modeling
# base query:  https://www.sciencedirect.com/search?qs=%22BIM%22%20%2B%20%22Thermal%20comfort%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22BIM%22%20%2B%20%22Thermal%20comfort%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22BIM%22%20%2B%20%22Electricity%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22BIM%22%20%2B%20%22Electricity%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22BIM%22%20%2B%20%22Solar%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22BIM%22%20%2B%20%22Solar%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22BIM%22%20%2B%20%22Wind%20power%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22BIM%22%20%2B%20%22Wind%20power%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22BIM%22%20%2B%20%22Green%20infrastructure%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22BIM%22%20%2B%20%22Green%20infrastructure%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22BIM%22%20%2B%20%22Life%20cycle%20assessment%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22BIM%22%20%2B%20%22Life%20cycle%20assessment%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20Information%20Modelling%22%20%2B%20%22Green%20Building%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20Information%20Modelling%22%20%2B%20%22Green%20Building%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20Information%20Modelling%22%20%2B%20%22Green%20Buildings%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20Information%20Modelling%22%20%2B%20%22Green%20Buildings%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20Information%20Modelling%22%20%2B%20%22Sustainable%20building%22
# pageResults:  1
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20Information%20Modelling%22%20%2B%20%22Sustainable%20building%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# Reading result:  19
# Title:  Systems modelling for sustainable building design
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20Information%20Modelling%22%20%2B%20%22Sustainable%20buildings%22
# pageResults:  1
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20Information%20Modelling%22%20%2B%20%22Sustainable%20buildings%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# Reading result:  20
# Title:  Systems modelling for sustainable building design
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20Information%20Modelling%22%20%2B%20%22Environmentally%20friendly%20design%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20Information%20Modelling%22%20%2B%20%22Environmentally%20friendly%20design%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20Information%20Modelling%22%20%2B%20%22Sustainability%22
# pageResults:  5
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20Information%20Modelling%22%20%2B%20%22Sustainability%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# Reading result:  21
# Title:  Methods for the Automated Assignment and Comparison of Building Damage Geometries
# Reading result:  22
# Title:  Digital buildings – Challenges and opportunities
# Reading result:  23
# Title:  Systems modelling for sustainable building design
# Reading result:  24
# Title:  A cloud approach to unified lifecycle data management in architecture, engineering, construction and facilities management: Integrating BIMs and SNS
# Reading result:  25
# Title:  BIM extension for the sustainability appraisal of conceptual steel design
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20Information%20Modelling%22%20%2B%20%22Sustainable%20development%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20Information%20Modelling%22%20%2B%20%22Sustainable%20development%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20Information%20Modelling%22%20%2B%20%22Energy%22
# pageResults:  12
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20Information%20Modelling%22%20%2B%20%22Energy%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# Reading result:  26
# Title:  Semantic information alignment of BIMs to computer-interpretable regulations using ontologies and deep learning
# Reading result:  27
# Title:  Quick energy prediction and comparison of options at the early design stage
# Reading result:  28
# Title:  BIMification: How to create and use BIM for retrofitting
# Reading result:  29
# Title:  Forecasting building energy consumption: Adaptive long-short term memory neural networks driven by genetic algorithm
# Reading result:  30
# Title:  BIM-enabled facilities operation and maintenance: A review
# Reading result:  31
# Title:  A meta-model approach for formal specification and consistent management of multi-LOD building models
# Reading result:  32
# Title:  Information requirements for multi-level-of-development BIM using sensitivity analysis for energy performance
# Reading result:  33
# Title:  3D as-is building energy modeling and diagnostics: A review of the state-of-the-art
# Reading result:  34
# Title:  General system architecture for BIM: An integrated approach for design and analysis
# Reading result:  35
# Title:  Self-corrective knowledge-based hybrid tracking system using BIM and multimodal sensors
# Reading result:  36
# Title:  Systems modelling for sustainable building design
# Reading result:  37
# Title:  Linking building data in the cloud: Integrating cross-domain building data using linked data
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20Information%20Modelling%22%20%2B%20%22Water%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20Information%20Modelling%22%20%2B%20%22Water%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20Information%20Modelling%22%20%2B%20%22Waste%22
# pageResults:  2
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20Information%20Modelling%22%20%2B%20%22Waste%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# Reading result:  38
# Title:  Automatic design and planning of scaffolding systems using building information modeling
# Reading result:  39
# Title:  Can we grow buildings? Concepts and requirements for automated nano- to meter-scale building
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20Information%20Modelling%22%20%2B%20%22Thermal%20comfort%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20Information%20Modelling%22%20%2B%20%22Thermal%20comfort%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20Information%20Modelling%22%20%2B%20%22Electricity%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20Information%20Modelling%22%20%2B%20%22Electricity%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20Information%20Modelling%22%20%2B%20%22Solar%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20Information%20Modelling%22%20%2B%20%22Solar%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20Information%20Modelling%22%20%2B%20%22Wind%20power%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20Information%20Modelling%22%20%2B%20%22Wind%20power%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20Information%20Modelling%22%20%2B%20%22Green%20infrastructure%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20Information%20Modelling%22%20%2B%20%22Green%20infrastructure%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20Information%20Modelling%22%20%2B%20%22Life%20cycle%20assessment%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20Information%20Modelling%22%20%2B%20%22Life%20cycle%20assessment%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20information%20model%22%20%2B%20%22Green%20Building%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20information%20model%22%20%2B%20%22Green%20Building%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20information%20model%22%20%2B%20%22Green%20Buildings%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20information%20model%22%20%2B%20%22Green%20Buildings%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20information%20model%22%20%2B%20%22Sustainable%20building%22
# pageResults:  1
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20information%20model%22%20%2B%20%22Sustainable%20building%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# Reading result:  40
# Title:  Systems modelling for sustainable building design
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20information%20model%22%20%2B%20%22Sustainable%20buildings%22
# pageResults:  1
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20information%20model%22%20%2B%20%22Sustainable%20buildings%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# Reading result:  41
# Title:  Systems modelling for sustainable building design
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20information%20model%22%20%2B%20%22Environmentally%20friendly%20design%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20information%20model%22%20%2B%20%22Environmentally%20friendly%20design%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20information%20model%22%20%2B%20%22Sustainability%22
# pageResults:  5
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20information%20model%22%20%2B%20%22Sustainability%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# Reading result:  42
# Title:  Methods for the Automated Assignment and Comparison of Building Damage Geometries
# Reading result:  43
# Title:  Digital buildings – Challenges and opportunities
# Reading result:  44
# Title:  Systems modelling for sustainable building design
# Reading result:  45
# Title:  A cloud approach to unified lifecycle data management in architecture, engineering, construction and facilities management: Integrating BIMs and SNS
# Reading result:  46
# Title:  BIM extension for the sustainability appraisal of conceptual steel design
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20information%20model%22%20%2B%20%22Sustainable%20development%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20information%20model%22%20%2B%20%22Sustainable%20development%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20information%20model%22%20%2B%20%22Energy%22
# pageResults:  12
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20information%20model%22%20%2B%20%22Energy%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# Reading result:  47
# Title:  Semantic information alignment of BIMs to computer-interpretable regulations using ontologies and deep learning
# Reading result:  48
# Title:  Quick energy prediction and comparison of options at the early design stage
# Reading result:  49
# Title:  BIMification: How to create and use BIM for retrofitting
# Reading result:  50
# Title:  Forecasting building energy consumption: Adaptive long-short term memory neural networks driven by genetic algorithm
# Reading result:  51
# Title:  BIM-enabled facilities operation and maintenance: A review
# Reading result:  52
# Title:  A meta-model approach for formal specification and consistent management of multi-LOD building models
# Reading result:  53
# Title:  Information requirements for multi-level-of-development BIM using sensitivity analysis for energy performance
# Reading result:  54
# Title:  3D as-is building energy modeling and diagnostics: A review of the state-of-the-art
# Reading result:  55
# Title:  General system architecture for BIM: An integrated approach for design and analysis
# Reading result:  56
# Title:  Self-corrective knowledge-based hybrid tracking system using BIM and multimodal sensors
# Reading result:  57
# Title:  Systems modelling for sustainable building design
# Reading result:  58
# Title:  Linking building data in the cloud: Integrating cross-domain building data using linked data
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20information%20model%22%20%2B%20%22Water%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20information%20model%22%20%2B%20%22Water%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20information%20model%22%20%2B%20%22Waste%22
# pageResults:  2
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20information%20model%22%20%2B%20%22Waste%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# Reading result:  59
# Title:  Automatic design and planning of scaffolding systems using building information modeling
# Reading result:  60
# Title:  Can we grow buildings? Concepts and requirements for automated nano- to meter-scale building
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20information%20model%22%20%2B%20%22Thermal%20comfort%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20information%20model%22%20%2B%20%22Thermal%20comfort%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20information%20model%22%20%2B%20%22Electricity%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20information%20model%22%20%2B%20%22Electricity%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20information%20model%22%20%2B%20%22Solar%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20information%20model%22%20%2B%20%22Solar%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20information%20model%22%20%2B%20%22Wind%20power%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20information%20model%22%20%2B%20%22Wind%20power%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20information%20model%22%20%2B%20%22Green%20infrastructure%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20information%20model%22%20%2B%20%22Green%20infrastructure%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20information%20model%22%20%2B%20%22Life%20cycle%20assessment%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20information%20model%22%20%2B%20%22Life%20cycle%20assessment%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%226D%20BIM%22%20%2B%20%22Green%20Building%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%226D%20BIM%22%20%2B%20%22Green%20Building%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%226D%20BIM%22%20%2B%20%22Green%20Buildings%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%226D%20BIM%22%20%2B%20%22Green%20Buildings%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%226D%20BIM%22%20%2B%20%22Sustainable%20building%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%226D%20BIM%22%20%2B%20%22Sustainable%20building%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%226D%20BIM%22%20%2B%20%22Sustainable%20buildings%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%226D%20BIM%22%20%2B%20%22Sustainable%20buildings%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%226D%20BIM%22%20%2B%20%22Environmentally%20friendly%20design%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%226D%20BIM%22%20%2B%20%22Environmentally%20friendly%20design%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%226D%20BIM%22%20%2B%20%22Sustainability%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%226D%20BIM%22%20%2B%20%22Sustainability%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%226D%20BIM%22%20%2B%20%22Sustainable%20development%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%226D%20BIM%22%20%2B%20%22Sustainable%20development%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%226D%20BIM%22%20%2B%20%22Energy%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%226D%20BIM%22%20%2B%20%22Energy%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%226D%20BIM%22%20%2B%20%22Water%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%226D%20BIM%22%20%2B%20%22Water%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%226D%20BIM%22%20%2B%20%22Waste%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%226D%20BIM%22%20%2B%20%22Waste%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%226D%20BIM%22%20%2B%20%22Thermal%20comfort%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%226D%20BIM%22%20%2B%20%22Thermal%20comfort%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%226D%20BIM%22%20%2B%20%22Electricity%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%226D%20BIM%22%20%2B%20%22Electricity%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%226D%20BIM%22%20%2B%20%22Solar%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%226D%20BIM%22%20%2B%20%22Solar%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%226D%20BIM%22%20%2B%20%22Wind%20power%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%226D%20BIM%22%20%2B%20%22Wind%20power%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%226D%20BIM%22%20%2B%20%22Green%20infrastructure%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%226D%20BIM%22%20%2B%20%22Green%20infrastructure%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%226D%20BIM%22%20%2B%20%22Life%20cycle%20assessment%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%226D%20BIM%22%20%2B%20%22Life%20cycle%20assessment%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Digital%20construction%22%20%2B%20%22Green%20Building%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Digital%20construction%22%20%2B%20%22Green%20Building%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Digital%20construction%22%20%2B%20%22Green%20Buildings%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Digital%20construction%22%20%2B%20%22Green%20Buildings%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Digital%20construction%22%20%2B%20%22Sustainable%20building%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Digital%20construction%22%20%2B%20%22Sustainable%20building%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Digital%20construction%22%20%2B%20%22Sustainable%20buildings%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Digital%20construction%22%20%2B%20%22Sustainable%20buildings%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Digital%20construction%22%20%2B%20%22Environmentally%20friendly%20design%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Digital%20construction%22%20%2B%20%22Environmentally%20friendly%20design%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Digital%20construction%22%20%2B%20%22Sustainability%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Digital%20construction%22%20%2B%20%22Sustainability%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Digital%20construction%22%20%2B%20%22Sustainable%20development%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Digital%20construction%22%20%2B%20%22Sustainable%20development%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Digital%20construction%22%20%2B%20%22Energy%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Digital%20construction%22%20%2B%20%22Energy%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Digital%20construction%22%20%2B%20%22Water%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Digital%20construction%22%20%2B%20%22Water%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Digital%20construction%22%20%2B%20%22Waste%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Digital%20construction%22%20%2B%20%22Waste%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Digital%20construction%22%20%2B%20%22Thermal%20comfort%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Digital%20construction%22%20%2B%20%22Thermal%20comfort%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Digital%20construction%22%20%2B%20%22Electricity%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Digital%20construction%22%20%2B%20%22Electricity%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Digital%20construction%22%20%2B%20%22Solar%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Digital%20construction%22%20%2B%20%22Solar%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Digital%20construction%22%20%2B%20%22Wind%20power%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Digital%20construction%22%20%2B%20%22Wind%20power%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Digital%20construction%22%20%2B%20%22Green%20infrastructure%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Digital%20construction%22%20%2B%20%22Green%20infrastructure%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Digital%20construction%22%20%2B%20%22Life%20cycle%20assessment%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Digital%20construction%22%20%2B%20%22Life%20cycle%20assessment%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Smart%20construction%22%20%2B%20%22Green%20Building%22
# pageResults:  0
# page:  1
# In page:  0
# ...
# base query:  https://www.sciencedirect.com/search?qs=%22Smart%20construction%22%20%2B%20%22Green%20Buildings%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Smart%20construction%22%20%2B%20%22Green%20Buildings%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Smart%20construction%22%20%2B%20%22Sustainable%20building%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Smart%20construction%22%20%2B%20%22Sustainable%20building%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Smart%20construction%22%20%2B%20%22Sustainable%20buildings%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Smart%20construction%22%20%2B%20%22Sustainable%20buildings%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Smart%20construction%22%20%2B%20%22Environmentally%20friendly%20design%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Smart%20construction%22%20%2B%20%22Environmentally%20friendly%20design%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Smart%20construction%22%20%2B%20%22Sustainability%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Smart%20construction%22%20%2B%20%22Sustainability%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Smart%20construction%22%20%2B%20%22Sustainable%20development%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Smart%20construction%22%20%2B%20%22Sustainable%20development%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Smart%20construction%22%20%2B%20%22Energy%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Smart%20construction%22%20%2B%20%22Energy%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Smart%20construction%22%20%2B%20%22Water%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Smart%20construction%22%20%2B%20%22Water%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Smart%20construction%22%20%2B%20%22Waste%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Smart%20construction%22%20%2B%20%22Waste%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Smart%20construction%22%20%2B%20%22Thermal%20comfort%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Smart%20construction%22%20%2B%20%22Thermal%20comfort%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Smart%20construction%22%20%2B%20%22Electricity%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Smart%20construction%22%20%2B%20%22Electricity%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Smart%20construction%22%20%2B%20%22Solar%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Smart%20construction%22%20%2B%20%22Solar%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Smart%20construction%22%20%2B%20%22Wind%20power%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Smart%20construction%22%20%2B%20%22Wind%20power%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Smart%20construction%22%20%2B%20%22Green%20infrastructure%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Smart%20construction%22%20%2B%20%22Green%20infrastructure%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Smart%20construction%22%20%2B%20%22Life%20cycle%20assessment%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Smart%20construction%22%20%2B%20%22Life%20cycle%20assessment%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Digital%20engineering%22%20%2B%20%22Green%20Building%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Digital%20engineering%22%20%2B%20%22Green%20Building%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Digital%20engineering%22%20%2B%20%22Green%20Buildings%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Digital%20engineering%22%20%2B%20%22Green%20Buildings%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Digital%20engineering%22%20%2B%20%22Sustainable%20building%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Digital%20engineering%22%20%2B%20%22Sustainable%20building%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Digital%20engineering%22%20%2B%20%22Sustainable%20buildings%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Digital%20engineering%22%20%2B%20%22Sustainable%20buildings%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Digital%20engineering%22%20%2B%20%22Environmentally%20friendly%20design%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Digital%20engineering%22%20%2B%20%22Environmentally%20friendly%20design%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Digital%20engineering%22%20%2B%20%22Sustainability%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Digital%20engineering%22%20%2B%20%22Sustainability%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Digital%20engineering%22%20%2B%20%22Sustainable%20development%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Digital%20engineering%22%20%2B%20%22Sustainable%20development%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Digital%20engineering%22%20%2B%20%22Energy%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Digital%20engineering%22%20%2B%20%22Energy%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Digital%20engineering%22%20%2B%20%22Water%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Digital%20engineering%22%20%2B%20%22Water%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Digital%20engineering%22%20%2B%20%22Waste%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Digital%20engineering%22%20%2B%20%22Waste%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Digital%20engineering%22%20%2B%20%22Thermal%20comfort%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Digital%20engineering%22%20%2B%20%22Thermal%20comfort%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Digital%20engineering%22%20%2B%20%22Electricity%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Digital%20engineering%22%20%2B%20%22Electricity%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Digital%20engineering%22%20%2B%20%22Solar%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Digital%20engineering%22%20%2B%20%22Solar%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Digital%20engineering%22%20%2B%20%22Wind%20power%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Digital%20engineering%22%20%2B%20%22Wind%20power%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Digital%20engineering%22%20%2B%20%22Green%20infrastructure%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Digital%20engineering%22%20%2B%20%22Green%20infrastructure%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Digital%20engineering%22%20%2B%20%22Life%20cycle%20assessment%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Digital%20engineering%22%20%2B%20%22Life%20cycle%20assessment%22&show=25&publicationTitles=272292&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com

# %%
df1 = df
df['journalName'] = str(idNo)
fileSave = 'kgRawData/SD/sd-kg'+idNo+'.csv'
df.to_csv(fileSave)

# %%
df
# Out:
#                        searchTerm1              searchTerm2  \
# 0                              BIM   Sustainable%20building
# 1                              BIM  Sustainable%20buildings
# 2                              BIM           Sustainability
# 3                              BIM           Sustainability
# 4                              BIM           Sustainability
# ..                             ...                      ...
# 56  Building%20information%20model                   Energy
# 57  Building%20information%20model                   Energy
# 58  Building%20information%20model                   Energy
# 59  Building%20information%20model                    Waste
# 60  Building%20information%20model                    Waste
#
#                                                   url  \
# 0   https://www.sciencedirect.com//science/article...
# 1   https://www.sciencedirect.com//science/article...
# 2   https://www.sciencedirect.com//science/article...
# 3   https://www.sciencedirect.com//science/article...
# 4   https://www.sciencedirect.com//science/article...
# ..                                                ...
# 56  https://www.sciencedirect.com//science/article...
# 57  https://www.sciencedirect.com//science/article...
# 58  https://www.sciencedirect.com//science/article...
# 59  https://www.sciencedirect.com//science/article...
# 60  https://www.sciencedirect.com//science/article...
#
#                                                 Title  section0  \
# 0   Systems modelling for sustainable building design  Abstract
# 1   Systems modelling for sustainable building design  Abstract
# 2   BIM extension for the sustainability appraisal...  Abstract
# 3   Systems modelling for sustainable building design  Abstract
# 4    Digital buildings – Challenges and opportunities  Abstract
# ..                                                ...       ...
# 56  Self-corrective knowledge-based hybrid trackin...  Abstract
# 57  Systems modelling for sustainable building design  Abstract
# 58  Linking building data in the cloud: Integratin...  Abstract
# 59  Automatic design and planning of scaffolding s...  Abstract
# 60  Can we grow buildings? Concepts and requiremen...  Abstract
#
#                                          sectionData0         section1  \
# 0   To support performance-oriented modelling for ...  1. Introduction
# 1   To support performance-oriented modelling for ...  1. Introduction
# 2   Contemporary advancements in Information Techn...  1. Introduction
# 3   To support performance-oriented modelling for ...  1. Introduction
# 4   This paper considers the wider implications of...  1. Introduction
# ..                                                ...              ...
# 56  Researchers have recently devoted considerable...  1. Introduction
# 57  To support performance-oriented modelling for ...  1. Introduction
# 58  Within the operational phase buildings are now...  1. Introduction
# 59  Considering their significant impact on constr...  1. Introduction
# 60  The construction industry will have to find ne...  1. Introduction
#
#                                          sectionData1  \
# 0   Building energy consumption comprises approxim...
# 1   Building energy consumption comprises approxim...
# 2   The design stage presents the best opportunity...
# 3   Building energy consumption comprises approxim...
# 4   Society currently faces many challenges dealin...
# ..                                                ...
# 56  The use of tracking technology to detect the m...
# 57  Building energy consumption comprises approxim...
# 58  The holistic management and maintenance of fac...
# 59  Temporary facilities such as scaffolding syste...
# 60  Since the beginning of their evolution, humans...
#
#                                              section2  \
# 0          2. The Parametric Systems Modelling method
# 1          2. The Parametric Systems Modelling method
# 2                                       2. Background
# 3          2. The Parametric Systems Modelling method
# 4                   2. Building information modelling
# ..                                                ...
# 56                               2. Literature review
# 57         2. The Parametric Systems Modelling method
# 58   2. The case for cross-domain information sharing
# 59                                      2. Background
# 60  2. The concept of building from nano to meter-...
#
#                                          sectionData2  ... sectionData15  \
# 0   Systems modelling for building design and othe...  ...           NaN
# 1   Systems modelling for building design and othe...  ...           NaN
# 2   The fragmented nature of the AEC industry is l...  ...           NaN
# 3   Systems modelling for building design and othe...  ...           NaN
# 4   The term BIM has been adopted by the major ven...  ...           NaN
# ..                                                ...  ...           ...
# 56  This section reviews the existing literature f...  ...           NaN
# 57  Systems modelling for building design and othe...  ...           NaN
# 58  Most building costs are experienced during the...  ...           NaN
# 59  The production plans of construction projects ...  ...           NaN
# 60  A top-down concept has been developed followin...  ...           NaN
#
#    section16 sectionData16 section17 sectionData17 section18 sectionData18  \
# 0        NaN           NaN       NaN           NaN       NaN           NaN
# 1        NaN           NaN       NaN           NaN       NaN           NaN
# 2        NaN           NaN       NaN           NaN       NaN           NaN
# 3        NaN           NaN       NaN           NaN       NaN           NaN
# 4        NaN           NaN       NaN           NaN       NaN           NaN
# ..       ...           ...       ...           ...       ...           ...
# 56       NaN           NaN       NaN           NaN       NaN           NaN
# 57       NaN           NaN       NaN           NaN       NaN           NaN
# 58       NaN           NaN       NaN           NaN       NaN           NaN
# 59       NaN           NaN       NaN           NaN       NaN           NaN
# 60       NaN           NaN       NaN           NaN       NaN           NaN
#
#    section19 sectionData19 journalName
# 0        NaN           NaN      272292
# 1        NaN           NaN      272292
# 2        NaN           NaN      272292
# 3        NaN           NaN      272292
# 4        NaN           NaN      272292
# ..       ...           ...         ...
# 56       NaN           NaN      272292
# 57       NaN           NaN      272292
# 58       NaN           NaN      272292
# 59       NaN           NaN      272292
# 60       NaN           NaN      272292
#
# [61 rows x 45 columns]

# %%
idNo = '272292'

import pandas as pd
# filePath = 
data = pd.read_csv('kgRawData/SD/sd-kg' + idNo + '.csv')
data['presence'] = False

searchTerm1 = ['BIM' , 'Building Information Modelling','Building information model','6D BIM', 'Digital construction','Smart construction','Digital engineering']
searchTerm2 = ['Green Building' , 'Green Buildings','Sustainable building','Sustainable buildings','Environmentally friendly design' , 'Sustainability' , 'Sustainable development' , 'Energy','Water' ,'Waste' , 'Thermal comfort','Electricity' ,'Solar','Wind power' , 'Green infrastructure','Life cycle assessment']

validEntries = []

for i in range(data.shape[0]):    
    for st1 in searchTerm1:
        for st2 in searchTerm2:
            if (st1 in data['sectionData0'][i]) and (st2 in data['sectionData0'][i]):
                data['presence'][i] = True
                validEntries.append(i)

uniqueValidEntries = list(set(validEntries))

uniqueDf = pd.DataFrame()
uniqueDf.to_csv('blankFile.csv')

columnNames = ['searchTerm1','searchTerm2','url','Title']

uniqueDf = pd.read_csv("blankFile.csv", names= columnNames , header = None)
uniqueDf = uniqueDf.iloc[1:]

for i in range(20):
    section = "section" + str(i)
    sectionData = "sectionData" + str(i)
    uniqueDf[section] = ''
    uniqueDf[sectionData] = ''
    
for entry in range(len(uniqueValidEntries)):
    uniqueDf.loc[entry] = data.loc[uniqueValidEntries[entry]]    
    

uniqueDf.to_csv('kgRawData/SD/cleanSd-kg'+ idNo + '.csv')

print(len(uniqueDf))
# Out:
# 9
# <ipython-input-6-4213da2977e2>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['presence'][i] = True

# %%
uniqueDf
# Out:
#                           searchTerm1     searchTerm2  \
# 0                                 BIM  Sustainability
# 1  Building%20Information%20Modelling          Energy
# 2                                 BIM          Energy
# 3                                 BIM          Energy
# 4      Building%20information%20model  Sustainability
# 5      Building%20information%20model          Energy
# 6      Building%20information%20model          Energy
# 7  Building%20Information%20Modelling  Sustainability
# 8  Building%20Information%20Modelling          Energy
#
#                                                  url  \
# 0  https://www.sciencedirect.com//science/article...
# 1  https://www.sciencedirect.com//science/article...
# 2  https://www.sciencedirect.com//science/article...
# 3  https://www.sciencedirect.com//science/article...
# 4  https://www.sciencedirect.com//science/article...
# 5  https://www.sciencedirect.com//science/article...
# 6  https://www.sciencedirect.com//science/article...
# 7  https://www.sciencedirect.com//science/article...
# 8  https://www.sciencedirect.com//science/article...
#
#                                                Title  section0  \
# 0  BIM extension for the sustainability appraisal...  Abstract
# 1  Self-corrective knowledge-based hybrid trackin...  Abstract
# 2  Quick energy prediction and comparison of opti...  Abstract
# 3  Self-corrective knowledge-based hybrid trackin...  Abstract
# 4  BIM extension for the sustainability appraisal...  Abstract
# 5  Quick energy prediction and comparison of opti...  Abstract
# 6  Self-corrective knowledge-based hybrid trackin...  Abstract
# 7  BIM extension for the sustainability appraisal...  Abstract
# 8  Quick energy prediction and comparison of opti...  Abstract
#
#                                         sectionData0         section1  \
# 0  Contemporary advancements in Information Techn...  1. Introduction
# 1  Researchers have recently devoted considerable...  1. Introduction
# 2  The energy-efficient building design requires ...  1. Introduction
# 3  Researchers have recently devoted considerable...  1. Introduction
# 4  Contemporary advancements in Information Techn...  1. Introduction
# 5  The energy-efficient building design requires ...  1. Introduction
# 6  Researchers have recently devoted considerable...  1. Introduction
# 7  Contemporary advancements in Information Techn...  1. Introduction
# 8  The energy-efficient building design requires ...  1. Introduction
#
#                                         sectionData1                 section2  \
# 0  The design stage presents the best opportunity...            2. Background
# 1  The use of tracking technology to detect the m...     2. Literature review
# 2  The energy-efficient building design is an ess...  2. Research methodology
# 3  The use of tracking technology to detect the m...     2. Literature review
# 4  The design stage presents the best opportunity...            2. Background
# 5  The energy-efficient building design is an ess...  2. Research methodology
# 6  The use of tracking technology to detect the m...     2. Literature review
# 7  The design stage presents the best opportunity...            2. Background
# 8  The energy-efficient building design is an ess...  2. Research methodology
#
#                                         sectionData2  ... section15  \
# 0  The fragmented nature of the AEC industry is l...  ...       NaN
# 1  This section reviews the existing literature f...  ...       NaN
# 2  The research methodology is presented in four ...  ...       NaN
# 3  This section reviews the existing literature f...  ...       NaN
# 4  The fragmented nature of the AEC industry is l...  ...       NaN
# 5  The research methodology is presented in four ...  ...       NaN
# 6  This section reviews the existing literature f...  ...       NaN
# 7  The fragmented nature of the AEC industry is l...  ...       NaN
# 8  The research methodology is presented in four ...  ...       NaN
#
#   sectionData15 section16 sectionData16 section17 sectionData17 section18  \
# 0           NaN       NaN           NaN       NaN           NaN       NaN
# 1           NaN       NaN           NaN       NaN           NaN       NaN
# 2           NaN       NaN           NaN       NaN           NaN       NaN
# 3           NaN       NaN           NaN       NaN           NaN       NaN
# 4           NaN       NaN           NaN       NaN           NaN       NaN
# 5           NaN       NaN           NaN       NaN           NaN       NaN
# 6           NaN       NaN           NaN       NaN           NaN       NaN
# 7           NaN       NaN           NaN       NaN           NaN       NaN
# 8           NaN       NaN           NaN       NaN           NaN       NaN
#
#   sectionData18 section19 sectionData19
# 0           NaN       NaN           NaN
# 1           NaN       NaN           NaN
# 2           NaN       NaN           NaN
# 3           NaN       NaN           NaN
# 4           NaN       NaN           NaN
# 5           NaN       NaN           NaN
# 6           NaN       NaN           NaN
# 7           NaN       NaN           NaN
# 8           NaN       NaN           NaN
#
# [9 rows x 44 columns]
