# %%
# Building and Environment
idNo = '271434'

# %%
import requests
from bs4 import BeautifulSoup
from pandas.io.html import read_html
import pandas as pd
import json
import csv

# %%
df = pd.DataFrame()
df.to_csv('blankFile.csv')

columnNames = ['searchTerm1','searchTerm2','url','Title']

df = pd.read_csv("blankFile.csv", names= columnNames , header = None)
df = df.iloc[1:]

for i in range(20):
    section = "section" + str(i)
    sectionData = "sectionData" + str(i)
    df[section] = ''
    df[sectionData] = ''

df
# Out:
# Empty DataFrame
# Columns: [searchTerm1, searchTerm2, url, Title, section0, sectionData0, section1, sectionData1, section2, sectionData2, section3, sectionData3, section4, sectionData4, section5, sectionData5, section6, sectionData6, section7, sectionData7, section8, sectionData8, section9, sectionData9, section10, sectionData10, section11, sectionData11, section12, sectionData12, section13, sectionData13, section14, sectionData14, section15, sectionData15, section16, sectionData16, section17, sectionData17, section18, sectionData18, section19, sectionData19]
# Index: []
#
# [0 rows x 44 columns]

# %%
df
# Out:
# Empty DataFrame
# Columns: [searchTerm1, searchTerm2, url, Title, section0, sectionData0, section1, sectionData1, section2, sectionData2, section3, sectionData3, section4, sectionData4, section5, sectionData5, section6, sectionData6, section7, sectionData7, section8, sectionData8, section9, sectionData9, section10, sectionData10, section11, sectionData11, section12, sectionData12, section13, sectionData13, section14, sectionData14, section15, sectionData15, section16, sectionData16, section17, sectionData17, section18, sectionData18, section19, sectionData19]
# Index: []
#
# [0 rows x 44 columns]

# %%
# searchTerm1 = ['Building Information Modelling']
# searchTerm2 = ['Green Buildings']

# searchTerm1 = ['BIM']
# searchTerm2 = ['Sustainability']

tc = 0

searchTerm1 = ['BIM' , 'Building Information Modelling','Building information model','6D BIM', 'Digital construction','Smart construction','Digital engineering']
searchTerm2 = ['Green Building' , 'Green Buildings','Sustainable building','Sustainable buildings','Environmentally friendly design' , 'Sustainability' , 'Sustainable development' , 'Energy','Water' ,'Waste' , 'Thermal comfort','Electricity' ,'Solar','Wind power' , 'Green infrastructure','Life cycle assessment']

counter = 0
programSearchTerms1 = []
programSearchTerms2 = []

for term2 in searchTerm2:
    text2 = ""
    terms2 = term2.split(' ')
    for t2 in terms2:
        text2 = text2 + t2 + "%20"

    fileIndex = text2.rfind("%20")
    te = text2[:fileIndex]
    programSearchTerms2.append(te)

print(programSearchTerms2)

for term1 in searchTerm1:
    text1 = ""
    terms1 = term1.split(' ')
    for t2 in terms1:
        text1 = text1 + t2 + "%20"

    fileIndex = text1.rfind("%20")
    te = text1[:fileIndex]
    programSearchTerms1.append(te)

print(programSearchTerms1)
# Out:
# ['Green%20Building', 'Green%20Buildings', 'Sustainable%20building', 'Sustainable%20buildings', 'Environmentally%20friendly%20design', 'Sustainability', 'Sustainable%20development', 'Energy', 'Water', 'Waste', 'Thermal%20comfort', 'Electricity', 'Solar', 'Wind%20power', 'Green%20infrastructure', 'Life%20cycle%20assessment']
# ['BIM', 'Building%20Information%20Modelling', 'Building%20information%20model', '6D%20BIM', 'Digital%20construction', 'Smart%20construction', 'Digital%20engineering']

# %%
def getData(link):
    browser = webdriver.Safari()
    browser.get(link)
    respData = browser.page_source
    browser.quit()
    parsed_html = BeautifulSoup(respData)
    
    title = parsed_html.find('span',{'class':'title-text'}).text
    print("Title: ",title)
    df.loc[row,'url'] = link
    df.loc[row,'Title'] = title
    
    absResults = parsed_html.find('div',{'class':'abstract author'})
    
    if absResults is not None:
        try:            
            df.loc[row,'section0'] = absResults.find('h2').text
            df.loc[row,'sectionData0'] = absResults.find('div').text
        except:
            df.loc[row,'section0'] = "None"
            df.loc[row,'sectionData0'] = "None"
    else:
        df.loc[row,'section0'] = "None"
        df.loc[row,'sectionData0'] = "None"

        
    sections = parsed_html.find('div',{'class':'Body u-font-serif'})
    if sections is not None:        
        sections = sections.find_next('div')
        count = 1 
        for section in sections:
            if section is not None: 
                sectionNo = 'section' + str(count)
                sectionData = 'sectionData' + str(count)
                try:
                    df.loc[row,sectionNo] = section.find('h2',{'class':'u-h3 u-margin-l-top u-margin-xs-bottom'}).text
                except:
                    df.loc[row,sectionNo] = "Some issue"
                    
                data = ''
                for para in section.findAll('p'):
                    data = data + para.text
                df.loc[row,sectionData] = data
            else:
                df.loc[row,sectionNo] = "None"
            count = count + 1

# %%
from bs4 import BeautifulSoup
from selenium import webdriver

# %%
baseUrl = 'https://www.sciencedirect.com/search/api?tak=%22'

querySet = []
row = 0
for item1 in programSearchTerms1:
    for item2 in programSearchTerms2:
        sq = 'https://www.sciencedirect.com/search?qs=%22' + item1 + '%22%20%2B%20%22' + item2 + '%22'
        print("base query: ",sq)
        query = baseUrl + item1 +"%22%20%2B%20%22"+ item2+"%22&show=25&publicationTitles=" + idNo + "&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com"
        
        # Call webdriver         
        browser = webdriver.Safari()
        browser.get(query)
        respData = browser.page_source
        browser.quit()

        # Clear html         
        respData = respData.replace('<html><head></head><body><pre style="word-wrap: break-word; white-space: pre-wrap;">',"")
        respData = respData.replace('</pre></body></html>',"")
        
        py_dic = json.loads(respData)
        
        # Finding the number of pages in the selected journals.         
        for key in py_dic:
            if key == 'resultsFound':
                pageResults = py_dic[key]
        print("pageResults: ",pageResults)                
                                
        if pageResults > 25:
            page = pageResults // 25
            lastPage = pageResults % 25
            if lastPage > 0:
                page = page + 1
        else:
            page = 1
        print("page: ",page)

        #         for p in range(2):        
        for p in range(page):
            print("In page: ",p)
            if p == 0:
                query = baseUrl + item1 +"%22%20%2B%20%22"+ item2+"%22&show=25&publicationTitles=" + idNo + "&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com"
            else:
                offset = '&offset='+str(p*25)
                query = baseUrl + item1 +"%22%20%2B%20%22"+ item2+"%22&show=25&publicationTitles=" + idNo + "&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com"
                
            print("search query: ",query)  
                
            # Call webdriver         
            browser = webdriver.Safari()
            browser.get(query)
            respData = browser.page_source
            browser.quit()
            # Load Json Data 

            respData = respData.replace('<html><head></head><body><pre style="word-wrap: break-word; white-space: pre-wrap;">',"")
            respData = respData.replace('</pre></body></html>',"")

            py_dic = json.loads(respData)                
            # Quit the browser 
            links = []
            for key in py_dic:
                if key == 'searchResults':
                    for searchR in py_dic[key]:
                        for search in searchR:
                            if search == 'pdf':
                                for linkR in searchR[search]:
                                    if linkR == 'getAccessLink':
                                        baseLink = 'https://www.sciencedirect.com/'
                                        link = baseLink +searchR[search][linkR]
                                        print('Reading result: ',row)
                                        df.loc[row,'searchTerm1'] = item1
                                        df.loc[row,'searchTerm2'] = item2
                                        getData(link)                                    
                                        row = row + 1
# Out:
# base query:  https://www.sciencedirect.com/search?qs=%22BIM%22%20%2B%20%22Green%20Building%22
# pageResults:  1
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22BIM%22%20%2B%20%22Green%20Building%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# Reading result:  0
# Title:  Integration of Building Information Modeling and Web Service Application Programming Interface for assessing building surroundings in early design stages
# base query:  https://www.sciencedirect.com/search?qs=%22BIM%22%20%2B%20%22Green%20Buildings%22
# pageResults:  1
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22BIM%22%20%2B%20%22Green%20Buildings%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# Reading result:  1
# Title:  Integration of Building Information Modeling and Web Service Application Programming Interface for assessing building surroundings in early design stages
# base query:  https://www.sciencedirect.com/search?qs=%22BIM%22%20%2B%20%22Sustainable%20building%22
# pageResults:  1
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22BIM%22%20%2B%20%22Sustainable%20building%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# Reading result:  2
# Title:  Sustainable material choice for construction projects: A Life Cycle Sustainability Assessment framework based on BIM and Fuzzy-AHP
# base query:  https://www.sciencedirect.com/search?qs=%22BIM%22%20%2B%20%22Sustainable%20buildings%22
# pageResults:  1
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22BIM%22%20%2B%20%22Sustainable%20buildings%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# Reading result:  3
# Title:  Sustainable material choice for construction projects: A Life Cycle Sustainability Assessment framework based on BIM and Fuzzy-AHP
# base query:  https://www.sciencedirect.com/search?qs=%22BIM%22%20%2B%20%22Environmentally%20friendly%20design%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22BIM%22%20%2B%20%22Environmentally%20friendly%20design%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22BIM%22%20%2B%20%22Sustainability%22
# pageResults:  9
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22BIM%22%20%2B%20%22Sustainability%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# Reading result:  4
# Title:  Greening existing buildings through Building Information Modelling: A review of the recent development
# Reading result:  5
# Title:  Implementing Life Cycle Sustainability Assessment during design stages in Building Information Modelling: From systematic literature review to a methodological approach
# Reading result:  6
# Title:  Sustainable material choice for construction projects: A Life Cycle Sustainability Assessment framework based on BIM and Fuzzy-AHP
# Reading result:  7
# Title:  BIM-based life cycle assessment and life cycle costing of an office building in Western Europe
# Reading result:  8
# Title:  Mixed method review for integrating building information modeling and life-cycle assessments
# Reading result:  9
# Title:  Integrating building information modeling and life cycle assessment in the early and detailed building design stages
# Reading result:  10
# Title:  Mapping the scientific research of the life cycle assessment in the construction industry: A scientometric analysis
# Reading result:  11
# Title:  Developing a topological information extraction model for space syntax analysis
# Reading result:  12
# Title:  Application of life-cycle assessment to early stage building design for reduced embodied environmental impacts
# base query:  https://www.sciencedirect.com/search?qs=%22BIM%22%20%2B%20%22Sustainable%20development%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22BIM%22%20%2B%20%22Sustainable%20development%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22BIM%22%20%2B%20%22Energy%22
# pageResults:  10
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22BIM%22%20%2B%20%22Energy%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# Reading result:  13
# Title:  Optimizing the evaluation of building envelope design for thermal performance using a BIM-based overall thermal transfer value calculation
# Reading result:  14
# Title:  Stations-oriented indoor localization (SOIL): A BIM-Based occupancy schedule modeling system
# Reading result:  15
# Title:  A new method for calculating the embodied carbon emissions from buildings in schematic design: Taking “building element” as basic unit
# Reading result:  16
# Title:  Integration of Building Information Modeling and Web Service Application Programming Interface for assessing building surroundings in early design stages
# Reading result:  17
# Title:  Ontology-based framework for building environmental monitoring and compliance checking under BIM environment
# Reading result:  18
# Title:  Implementing post-occupancy evaluation in social housing complemented with BIM: A case study in Chile
# Reading result:  19
# Title:  A holistic framework to utilize natural ventilation to optimize energy performance of residential high-rise buildings
# Reading result:  20
# Title:  Micro-climatization and real-time digitalization effects on energy efficiency based on user behavior
# Reading result:  21
# Title:  Mapping the scientific research of the life cycle assessment in the construction industry: A scientometric analysis
# Reading result:  22
# Title:  Requirements for applying LCA-based environmental impact assessment tools in the early stages of building design
# base query:  https://www.sciencedirect.com/search?qs=%22BIM%22%20%2B%20%22Water%22
# pageResults:  1
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22BIM%22%20%2B%20%22Water%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# Reading result:  23
# Title:  Mapping the scientific research of the life cycle assessment in the construction industry: A scientometric analysis
# base query:  https://www.sciencedirect.com/search?qs=%22BIM%22%20%2B%20%22Waste%22
# pageResults:  3
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22BIM%22%20%2B%20%22Waste%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# Reading result:  24
# Title:  Implementing Life Cycle Sustainability Assessment during design stages in Building Information Modelling: From systematic literature review to a methodological approach
# Reading result:  25
# Title:  Mixed method review for integrating building information modeling and life-cycle assessments
# Reading result:  26
# Title:  Mapping the scientific research of the life cycle assessment in the construction industry: A scientometric analysis
# base query:  https://www.sciencedirect.com/search?qs=%22BIM%22%20%2B%20%22Thermal%20comfort%22
# pageResults:  2
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22BIM%22%20%2B%20%22Thermal%20comfort%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# Reading result:  27
# Title:  BIM- and IoT-based virtual reality tool for real-time thermal comfort assessment in building enclosures
# Reading result:  28
# Title:  Integrating 4D thermal information with BIM for building envelope thermal performance analysis and thermal comfort evaluation in naturally ventilated environments
# base query:  https://www.sciencedirect.com/search?qs=%22BIM%22%20%2B%20%22Electricity%22
# pageResults:  1
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22BIM%22%20%2B%20%22Electricity%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# Reading result:  29
# Title:  A holistic framework to utilize natural ventilation to optimize energy performance of residential high-rise buildings
# base query:  https://www.sciencedirect.com/search?qs=%22BIM%22%20%2B%20%22Solar%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22BIM%22%20%2B%20%22Solar%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22BIM%22%20%2B%20%22Wind%20power%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22BIM%22%20%2B%20%22Wind%20power%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22BIM%22%20%2B%20%22Green%20infrastructure%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22BIM%22%20%2B%20%22Green%20infrastructure%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22BIM%22%20%2B%20%22Life%20cycle%20assessment%22
# pageResults:  9
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22BIM%22%20%2B%20%22Life%20cycle%20assessment%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# Reading result:  30
# Title:  BIM-based life cycle assessment and life cycle costing of an office building in Western Europe
# Reading result:  31
# Title:  BIM-DLCA: An integrated dynamic environmental impact assessment model for buildings
# Reading result:  32
# Title:  Implementing Life Cycle Sustainability Assessment during design stages in Building Information Modelling: From systematic literature review to a methodological approach
# Reading result:  33
# Title:  Mixed method review for integrating building information modeling and life-cycle assessments
# Reading result:  34
# Title:  LCA and BIM: Visualization of environmental potentials in building construction at early design stages
# Reading result:  35
# Title:  Integrating building information modeling and life cycle assessment in the early and detailed building design stages
# Reading result:  36
# Title:  Mapping the scientific research of the life cycle assessment in the construction industry: A scientometric analysis
# Reading result:  37
# Title:  Application of life-cycle assessment to early stage building design for reduced embodied environmental impacts
# Reading result:  38
# Title:  Requirements for applying LCA-based environmental impact assessment tools in the early stages of building design
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20Information%20Modelling%22%20%2B%20%22Green%20Building%22
# pageResults:  2
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20Information%20Modelling%22%20%2B%20%22Green%20Building%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# Reading result:  39
# Title:  Integration of Building Information Modeling and Web Service Application Programming Interface for assessing building surroundings in early design stages
# Reading result:  40
# Title:  Triple bottom line sustainability assessment of window-to-wall ratio in US office buildings
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20Information%20Modelling%22%20%2B%20%22Green%20Buildings%22
# pageResults:  2
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20Information%20Modelling%22%20%2B%20%22Green%20Buildings%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# Reading result:  41
# Title:  Integration of Building Information Modeling and Web Service Application Programming Interface for assessing building surroundings in early design stages
# Reading result:  42
# Title:  Triple bottom line sustainability assessment of window-to-wall ratio in US office buildings
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20Information%20Modelling%22%20%2B%20%22Sustainable%20building%22
# pageResults:  1
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20Information%20Modelling%22%20%2B%20%22Sustainable%20building%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# Reading result:  43
# Title:  Sustainable material choice for construction projects: A Life Cycle Sustainability Assessment framework based on BIM and Fuzzy-AHP
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20Information%20Modelling%22%20%2B%20%22Sustainable%20buildings%22
# pageResults:  1
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20Information%20Modelling%22%20%2B%20%22Sustainable%20buildings%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# Reading result:  44
# Title:  Sustainable material choice for construction projects: A Life Cycle Sustainability Assessment framework based on BIM and Fuzzy-AHP
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20Information%20Modelling%22%20%2B%20%22Environmentally%20friendly%20design%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20Information%20Modelling%22%20%2B%20%22Environmentally%20friendly%20design%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20Information%20Modelling%22%20%2B%20%22Sustainability%22
# pageResults:  12
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20Information%20Modelling%22%20%2B%20%22Sustainability%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# Reading result:  45
# Title:  Implementing Life Cycle Sustainability Assessment during design stages in Building Information Modelling: From systematic literature review to a methodological approach
# Reading result:  46
# Title:  Greening existing buildings through Building Information Modelling: A review of the recent development
# Reading result:  47
# Title:  Sustainable material choice for construction projects: A Life Cycle Sustainability Assessment framework based on BIM and Fuzzy-AHP
# Reading result:  48
# Title:  Sustainability framework for buildings via data analytics
# Reading result:  49
# Title:  Mixed method review for integrating building information modeling and life-cycle assessments
# Reading result:  50
# Title:  BIM-based life cycle assessment and life cycle costing of an office building in Western Europe
# Reading result:  51
# Title:  Integrating building information modeling and life cycle assessment in the early and detailed building design stages
# Reading result:  52
# Title:  Mapping the scientific research of the life cycle assessment in the construction industry: A scientometric analysis
# Reading result:  53
# Title:  Developing a topological information extraction model for space syntax analysis
# Reading result:  54
# Title:  Ten questions concerning co-simulation for performance prediction of advanced building envelopes
# Reading result:  55
# Title:  Triple bottom line sustainability assessment of window-to-wall ratio in US office buildings
# Reading result:  56
# Title:  Application of life-cycle assessment to early stage building design for reduced embodied environmental impacts
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20Information%20Modelling%22%20%2B%20%22Sustainable%20development%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20Information%20Modelling%22%20%2B%20%22Sustainable%20development%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20Information%20Modelling%22%20%2B%20%22Energy%22
# pageResults:  12
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20Information%20Modelling%22%20%2B%20%22Energy%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# Reading result:  57
# Title:  A holistic framework to utilize natural ventilation to optimize energy performance of residential high-rise buildings
# Reading result:  58
# Title:  Stations-oriented indoor localization (SOIL): A BIM-Based occupancy schedule modeling system
# Reading result:  59
# Title:  Mapping the scientific research of the life cycle assessment in the construction industry: A scientometric analysis
# Reading result:  60
# Title:  Triple bottom line sustainability assessment of window-to-wall ratio in US office buildings
# Reading result:  61
# Title:  Micro-climatization and real-time digitalization effects on energy efficiency based on user behavior
# Reading result:  62
# Title:  A new method for calculating the embodied carbon emissions from buildings in schematic design: Taking “building element” as basic unit
# Reading result:  63
# Title:  IEQ-Compass – A tool for holistic evaluation of potential indoor environmental quality
# Reading result:  64
# Title:  An ontology to represent energy-related occupant behavior in buildings. Part II: Implementation of the DNAS framework using an XML schema
# Reading result:  65
# Title:  Integration of Building Information Modeling and Web Service Application Programming Interface for assessing building surroundings in early design stages
# Reading result:  66
# Title:  Ten questions concerning co-simulation for performance prediction of advanced building envelopes
# Reading result:  67
# Title:  Ontology-based framework for building environmental monitoring and compliance checking under BIM environment
# Reading result:  68
# Title:  Optimizing the evaluation of building envelope design for thermal performance using a BIM-based overall thermal transfer value calculation
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20Information%20Modelling%22%20%2B%20%22Water%22
# pageResults:  1
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20Information%20Modelling%22%20%2B%20%22Water%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# Reading result:  69
# Title:  Mapping the scientific research of the life cycle assessment in the construction industry: A scientometric analysis
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20Information%20Modelling%22%20%2B%20%22Waste%22
# pageResults:  3
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20Information%20Modelling%22%20%2B%20%22Waste%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# Reading result:  70
# Title:  Implementing Life Cycle Sustainability Assessment during design stages in Building Information Modelling: From systematic literature review to a methodological approach
# Reading result:  71
# Title:  Mixed method review for integrating building information modeling and life-cycle assessments
# Reading result:  72
# Title:  Mapping the scientific research of the life cycle assessment in the construction industry: A scientometric analysis
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20Information%20Modelling%22%20%2B%20%22Thermal%20comfort%22
# pageResults:  2
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20Information%20Modelling%22%20%2B%20%22Thermal%20comfort%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# Reading result:  73
# Title:  BIM- and IoT-based virtual reality tool for real-time thermal comfort assessment in building enclosures
# Reading result:  74
# Title:  Integrating 4D thermal information with BIM for building envelope thermal performance analysis and thermal comfort evaluation in naturally ventilated environments
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20Information%20Modelling%22%20%2B%20%22Electricity%22
# pageResults:  1
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20Information%20Modelling%22%20%2B%20%22Electricity%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# Reading result:  75
# Title:  A holistic framework to utilize natural ventilation to optimize energy performance of residential high-rise buildings
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20Information%20Modelling%22%20%2B%20%22Solar%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20Information%20Modelling%22%20%2B%20%22Solar%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20Information%20Modelling%22%20%2B%20%22Wind%20power%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20Information%20Modelling%22%20%2B%20%22Wind%20power%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20Information%20Modelling%22%20%2B%20%22Green%20infrastructure%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20Information%20Modelling%22%20%2B%20%22Green%20infrastructure%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20Information%20Modelling%22%20%2B%20%22Life%20cycle%20assessment%22
# pageResults:  10
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20Information%20Modelling%22%20%2B%20%22Life%20cycle%20assessment%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# Reading result:  76
# Title:  Mixed method review for integrating building information modeling and life-cycle assessments
# Reading result:  77
# Title:  BIM-based life cycle assessment and life cycle costing of an office building in Western Europe
# Reading result:  78
# Title:  Implementing Life Cycle Sustainability Assessment during design stages in Building Information Modelling: From systematic literature review to a methodological approach
# Reading result:  79
# Title:  Integrating building information modeling and life cycle assessment in the early and detailed building design stages
# Reading result:  80
# Title:  LCA and BIM: Visualization of environmental potentials in building construction at early design stages
# Reading result:  81
# Title:  Mapping the scientific research of the life cycle assessment in the construction industry: A scientometric analysis
# Reading result:  82
# Title:  BIM-DLCA: An integrated dynamic environmental impact assessment model for buildings
# Reading result:  83
# Title:  Life cycle assessment in the building design process – A systematic literature review
# Reading result:  84
# Title:  Triple bottom line sustainability assessment of window-to-wall ratio in US office buildings
# Reading result:  85
# Title:  Application of life-cycle assessment to early stage building design for reduced embodied environmental impacts
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20information%20model%22%20%2B%20%22Green%20Building%22
# pageResults:  2
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20information%20model%22%20%2B%20%22Green%20Building%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# Reading result:  86
# Title:  Integration of Building Information Modeling and Web Service Application Programming Interface for assessing building surroundings in early design stages
# Reading result:  87
# Title:  Triple bottom line sustainability assessment of window-to-wall ratio in US office buildings
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20information%20model%22%20%2B%20%22Green%20Buildings%22
# pageResults:  2
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20information%20model%22%20%2B%20%22Green%20Buildings%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# Reading result:  88
# Title:  Integration of Building Information Modeling and Web Service Application Programming Interface for assessing building surroundings in early design stages
# Reading result:  89
# Title:  Triple bottom line sustainability assessment of window-to-wall ratio in US office buildings
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20information%20model%22%20%2B%20%22Sustainable%20building%22
# pageResults:  1
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20information%20model%22%20%2B%20%22Sustainable%20building%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# Reading result:  90
# Title:  Sustainable material choice for construction projects: A Life Cycle Sustainability Assessment framework based on BIM and Fuzzy-AHP
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20information%20model%22%20%2B%20%22Sustainable%20buildings%22
# pageResults:  1
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20information%20model%22%20%2B%20%22Sustainable%20buildings%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# Reading result:  91
# Title:  Sustainable material choice for construction projects: A Life Cycle Sustainability Assessment framework based on BIM and Fuzzy-AHP
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20information%20model%22%20%2B%20%22Environmentally%20friendly%20design%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20information%20model%22%20%2B%20%22Environmentally%20friendly%20design%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20information%20model%22%20%2B%20%22Sustainability%22
# pageResults:  12
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20information%20model%22%20%2B%20%22Sustainability%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# Reading result:  92
# Title:  Implementing Life Cycle Sustainability Assessment during design stages in Building Information Modelling: From systematic literature review to a methodological approach
# Reading result:  93
# Title:  Greening existing buildings through Building Information Modelling: A review of the recent development
# Reading result:  94
# Title:  Sustainable material choice for construction projects: A Life Cycle Sustainability Assessment framework based on BIM and Fuzzy-AHP
# Reading result:  95
# Title:  Sustainability framework for buildings via data analytics
# Reading result:  96
# Title:  Mixed method review for integrating building information modeling and life-cycle assessments
# Reading result:  97
# Title:  BIM-based life cycle assessment and life cycle costing of an office building in Western Europe
# Reading result:  98
# Title:  Integrating building information modeling and life cycle assessment in the early and detailed building design stages
# Reading result:  99
# Title:  Mapping the scientific research of the life cycle assessment in the construction industry: A scientometric analysis
# Reading result:  100
# Title:  Developing a topological information extraction model for space syntax analysis
# Reading result:  101
# Title:  Ten questions concerning co-simulation for performance prediction of advanced building envelopes
# Reading result:  102
# Title:  Triple bottom line sustainability assessment of window-to-wall ratio in US office buildings
# Reading result:  103
# Title:  Application of life-cycle assessment to early stage building design for reduced embodied environmental impacts
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20information%20model%22%20%2B%20%22Sustainable%20development%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20information%20model%22%20%2B%20%22Sustainable%20development%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20information%20model%22%20%2B%20%22Energy%22
# pageResults:  12
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20information%20model%22%20%2B%20%22Energy%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# Reading result:  104
# Title:  A holistic framework to utilize natural ventilation to optimize energy performance of residential high-rise buildings
# Reading result:  105
# Title:  Stations-oriented indoor localization (SOIL): A BIM-Based occupancy schedule modeling system
# Reading result:  106
# Title:  Mapping the scientific research of the life cycle assessment in the construction industry: A scientometric analysis
# Reading result:  107
# Title:  Triple bottom line sustainability assessment of window-to-wall ratio in US office buildings
# Reading result:  108
# Title:  Micro-climatization and real-time digitalization effects on energy efficiency based on user behavior
# Reading result:  109
# Title:  A new method for calculating the embodied carbon emissions from buildings in schematic design: Taking “building element” as basic unit
# Reading result:  110
# Title:  IEQ-Compass – A tool for holistic evaluation of potential indoor environmental quality
# Reading result:  111
# Title:  An ontology to represent energy-related occupant behavior in buildings. Part II: Implementation of the DNAS framework using an XML schema
# Reading result:  112
# Title:  Integration of Building Information Modeling and Web Service Application Programming Interface for assessing building surroundings in early design stages
# Reading result:  113
# Title:  Ten questions concerning co-simulation for performance prediction of advanced building envelopes
# Reading result:  114
# Title:  Ontology-based framework for building environmental monitoring and compliance checking under BIM environment
# Reading result:  115
# Title:  Optimizing the evaluation of building envelope design for thermal performance using a BIM-based overall thermal transfer value calculation
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20information%20model%22%20%2B%20%22Water%22
# pageResults:  1
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20information%20model%22%20%2B%20%22Water%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# Reading result:  116
# Title:  Mapping the scientific research of the life cycle assessment in the construction industry: A scientometric analysis
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20information%20model%22%20%2B%20%22Waste%22
# pageResults:  3
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20information%20model%22%20%2B%20%22Waste%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# Reading result:  117
# Title:  Implementing Life Cycle Sustainability Assessment during design stages in Building Information Modelling: From systematic literature review to a methodological approach
# Reading result:  118
# Title:  Mixed method review for integrating building information modeling and life-cycle assessments
# Reading result:  119
# Title:  Mapping the scientific research of the life cycle assessment in the construction industry: A scientometric analysis
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20information%20model%22%20%2B%20%22Thermal%20comfort%22
# pageResults:  2
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20information%20model%22%20%2B%20%22Thermal%20comfort%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# Reading result:  120
# Title:  BIM- and IoT-based virtual reality tool for real-time thermal comfort assessment in building enclosures
# Reading result:  121
# Title:  Integrating 4D thermal information with BIM for building envelope thermal performance analysis and thermal comfort evaluation in naturally ventilated environments
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20information%20model%22%20%2B%20%22Electricity%22
# pageResults:  1
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20information%20model%22%20%2B%20%22Electricity%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# Reading result:  122
# Title:  A holistic framework to utilize natural ventilation to optimize energy performance of residential high-rise buildings
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20information%20model%22%20%2B%20%22Solar%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20information%20model%22%20%2B%20%22Solar%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20information%20model%22%20%2B%20%22Wind%20power%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20information%20model%22%20%2B%20%22Wind%20power%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20information%20model%22%20%2B%20%22Green%20infrastructure%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20information%20model%22%20%2B%20%22Green%20infrastructure%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Building%20information%20model%22%20%2B%20%22Life%20cycle%20assessment%22
# pageResults:  10
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Building%20information%20model%22%20%2B%20%22Life%20cycle%20assessment%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# Reading result:  123
# Title:  Mixed method review for integrating building information modeling and life-cycle assessments
# Reading result:  124
# Title:  BIM-based life cycle assessment and life cycle costing of an office building in Western Europe
# Reading result:  125
# Title:  Implementing Life Cycle Sustainability Assessment during design stages in Building Information Modelling: From systematic literature review to a methodological approach
# Reading result:  126
# Title:  Integrating building information modeling and life cycle assessment in the early and detailed building design stages
# Reading result:  127
# Title:  LCA and BIM: Visualization of environmental potentials in building construction at early design stages
# Reading result:  128
# Title:  Mapping the scientific research of the life cycle assessment in the construction industry: A scientometric analysis
# Reading result:  129
# Title:  BIM-DLCA: An integrated dynamic environmental impact assessment model for buildings
# Reading result:  130
# Title:  Life cycle assessment in the building design process – A systematic literature review
# Reading result:  131
# Title:  Triple bottom line sustainability assessment of window-to-wall ratio in US office buildings
# Reading result:  132
# Title:  Application of life-cycle assessment to early stage building design for reduced embodied environmental impacts
# base query:  https://www.sciencedirect.com/search?qs=%226D%20BIM%22%20%2B%20%22Green%20Building%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%226D%20BIM%22%20%2B%20%22Green%20Building%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%226D%20BIM%22%20%2B%20%22Green%20Buildings%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%226D%20BIM%22%20%2B%20%22Green%20Buildings%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%226D%20BIM%22%20%2B%20%22Sustainable%20building%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%226D%20BIM%22%20%2B%20%22Sustainable%20building%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%226D%20BIM%22%20%2B%20%22Sustainable%20buildings%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%226D%20BIM%22%20%2B%20%22Sustainable%20buildings%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%226D%20BIM%22%20%2B%20%22Environmentally%20friendly%20design%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%226D%20BIM%22%20%2B%20%22Environmentally%20friendly%20design%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%226D%20BIM%22%20%2B%20%22Sustainability%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%226D%20BIM%22%20%2B%20%22Sustainability%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%226D%20BIM%22%20%2B%20%22Sustainable%20development%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%226D%20BIM%22%20%2B%20%22Sustainable%20development%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%226D%20BIM%22%20%2B%20%22Energy%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%226D%20BIM%22%20%2B%20%22Energy%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# ...
# base query:  https://www.sciencedirect.com/search?qs=%22Smart%20construction%22%20%2B%20%22Green%20Buildings%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Smart%20construction%22%20%2B%20%22Green%20Buildings%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Smart%20construction%22%20%2B%20%22Sustainable%20building%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Smart%20construction%22%20%2B%20%22Sustainable%20building%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Smart%20construction%22%20%2B%20%22Sustainable%20buildings%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Smart%20construction%22%20%2B%20%22Sustainable%20buildings%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Smart%20construction%22%20%2B%20%22Environmentally%20friendly%20design%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Smart%20construction%22%20%2B%20%22Environmentally%20friendly%20design%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Smart%20construction%22%20%2B%20%22Sustainability%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Smart%20construction%22%20%2B%20%22Sustainability%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Smart%20construction%22%20%2B%20%22Sustainable%20development%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Smart%20construction%22%20%2B%20%22Sustainable%20development%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Smart%20construction%22%20%2B%20%22Energy%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Smart%20construction%22%20%2B%20%22Energy%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Smart%20construction%22%20%2B%20%22Water%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Smart%20construction%22%20%2B%20%22Water%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Smart%20construction%22%20%2B%20%22Waste%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Smart%20construction%22%20%2B%20%22Waste%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Smart%20construction%22%20%2B%20%22Thermal%20comfort%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Smart%20construction%22%20%2B%20%22Thermal%20comfort%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Smart%20construction%22%20%2B%20%22Electricity%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Smart%20construction%22%20%2B%20%22Electricity%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Smart%20construction%22%20%2B%20%22Solar%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Smart%20construction%22%20%2B%20%22Solar%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Smart%20construction%22%20%2B%20%22Wind%20power%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Smart%20construction%22%20%2B%20%22Wind%20power%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Smart%20construction%22%20%2B%20%22Green%20infrastructure%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Smart%20construction%22%20%2B%20%22Green%20infrastructure%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Smart%20construction%22%20%2B%20%22Life%20cycle%20assessment%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Smart%20construction%22%20%2B%20%22Life%20cycle%20assessment%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Digital%20engineering%22%20%2B%20%22Green%20Building%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Digital%20engineering%22%20%2B%20%22Green%20Building%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Digital%20engineering%22%20%2B%20%22Green%20Buildings%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Digital%20engineering%22%20%2B%20%22Green%20Buildings%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Digital%20engineering%22%20%2B%20%22Sustainable%20building%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Digital%20engineering%22%20%2B%20%22Sustainable%20building%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Digital%20engineering%22%20%2B%20%22Sustainable%20buildings%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Digital%20engineering%22%20%2B%20%22Sustainable%20buildings%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Digital%20engineering%22%20%2B%20%22Environmentally%20friendly%20design%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Digital%20engineering%22%20%2B%20%22Environmentally%20friendly%20design%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Digital%20engineering%22%20%2B%20%22Sustainability%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Digital%20engineering%22%20%2B%20%22Sustainability%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Digital%20engineering%22%20%2B%20%22Sustainable%20development%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Digital%20engineering%22%20%2B%20%22Sustainable%20development%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Digital%20engineering%22%20%2B%20%22Energy%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Digital%20engineering%22%20%2B%20%22Energy%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Digital%20engineering%22%20%2B%20%22Water%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Digital%20engineering%22%20%2B%20%22Water%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Digital%20engineering%22%20%2B%20%22Waste%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Digital%20engineering%22%20%2B%20%22Waste%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Digital%20engineering%22%20%2B%20%22Thermal%20comfort%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Digital%20engineering%22%20%2B%20%22Thermal%20comfort%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Digital%20engineering%22%20%2B%20%22Electricity%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Digital%20engineering%22%20%2B%20%22Electricity%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Digital%20engineering%22%20%2B%20%22Solar%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Digital%20engineering%22%20%2B%20%22Solar%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Digital%20engineering%22%20%2B%20%22Wind%20power%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Digital%20engineering%22%20%2B%20%22Wind%20power%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Digital%20engineering%22%20%2B%20%22Green%20infrastructure%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Digital%20engineering%22%20%2B%20%22Green%20infrastructure%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com
# base query:  https://www.sciencedirect.com/search?qs=%22Digital%20engineering%22%20%2B%20%22Life%20cycle%20assessment%22
# pageResults:  0
# page:  1
# In page:  0
# search query:  https://www.sciencedirect.com/search/api?tak=%22Digital%20engineering%22%20%2B%20%22Life%20cycle%20assessment%22&show=25&publicationTitles=271434&t=7EN%252Bo5sQQ6zhZ%252BAoTco%252BCBn%252BbzsV301l1vJIS08F%252FfZyGd1BvBslIQLVrbHXEzqKNF6BecRyI0u5A30hykv1MD5FCWUf4DF7Nbn6utpsZ0muydTQtxvTP56QYrBeyn6WvKdDbfVcomCzYflUlyb3MA%253D%253D&hostname=www.sciencedirect.com

# %%
df
# Out:
#                         searchTerm1                searchTerm2  \
# 0                               BIM           Green%20Building
# 1                               BIM          Green%20Buildings
# 2                               BIM     Sustainable%20building
# 3                               BIM    Sustainable%20buildings
# 4                               BIM             Sustainability
# ..                              ...                        ...
# 128  Building%20information%20model  Life%20cycle%20assessment
# 129  Building%20information%20model  Life%20cycle%20assessment
# 130  Building%20information%20model  Life%20cycle%20assessment
# 131  Building%20information%20model  Life%20cycle%20assessment
# 132  Building%20information%20model  Life%20cycle%20assessment
#
#                                                    url  \
# 0    https://www.sciencedirect.com//science/article...
# 1    https://www.sciencedirect.com//science/article...
# 2    https://www.sciencedirect.com//science/article...
# 3    https://www.sciencedirect.com//science/article...
# 4    https://www.sciencedirect.com//science/article...
# ..                                                 ...
# 128  https://www.sciencedirect.com//science/article...
# 129  https://www.sciencedirect.com//science/article...
# 130  https://www.sciencedirect.com//science/article...
# 131  https://www.sciencedirect.com//science/article...
# 132  https://www.sciencedirect.com//science/article...
#
#                                                  Title  section0  \
# 0    Integration of Building Information Modeling a...  Abstract
# 1    Integration of Building Information Modeling a...  Abstract
# 2    Sustainable material choice for construction p...  Abstract
# 3    Sustainable material choice for construction p...  Abstract
# 4    Greening existing buildings through Building I...  Abstract
# ..                                                 ...       ...
# 128  Mapping the scientific research of the life cy...  Abstract
# 129  BIM-DLCA: An integrated dynamic environmental ...  Abstract
# 130  Life cycle assessment in the building design p...  Abstract
# 131  Triple bottom line sustainability assessment o...  Abstract
# 132  Application of life-cycle assessment to early ...  Abstract
#
#                                           sectionData0         section1  \
# 0    Many studies and green building rating systems...  1. Introduction
# 1    Many studies and green building rating systems...  1. Introduction
# 2    Construction professionals and researchers are...  1. Introduction
# 3    Construction professionals and researchers are...  1. Introduction
# 4    The use of Building Information Modelling (BIM...  1. Introduction
# ..                                                 ...              ...
# 128  The interest toward the life cycle assessment ...  1. Introduction
# 129  Life cycle assessment (LCA) is an important an...  1. Introduction
# 130  Buildings contribute a significant portion of ...  1. Introduction
# 131  The window-to-wall ratio (WWR), or the proport...  1. Introduction
# 132  Decisions made during a building's early desig...  1. Introduction
#
#                                           sectionData1  \
# 0    The Architecture, Engineering, and Constructio...
# 1    The Architecture, Engineering, and Constructio...
# 2    The construction industry is responsible for t...
# 3    The construction industry is responsible for t...
# 4    Building sector accounts for 36% of energy use...
# ..                                                 ...
# 128  The interest in the life cycle assessments (LC...
# 129  Human activities have increased carbon emissio...
# 130  The emerging climate crisis is driving rapid a...
# 131  The United Nations Environment Programme estim...
# 132  Buildings consume significant amounts of energ...
#
#                                               section2  \
# 0                      2. Implementation of components
# 1                      2. Implementation of components
# 2                                 2. Literature review
# 3                                 2. Literature review
# 4                    2. Review approach and strategies
# ..                                                 ...
# 128                                     2. Methodology
# 129                                     2. Methodology
# 130  2. Life cycle assessment within the building d...
# 131                                         2. Methods
# 132                               2. Literature review
#
#                                           sectionData2  ... sectionData15  \
# 0    The integration has two main parts, Dynamo cus...  ...           NaN
# 1    The integration has two main parts, Dynamo cus...  ...           NaN
# 2    A literature review of the proposed methodolog...  ...           NaN
# 3    A literature review of the proposed methodolog...  ...           NaN
# 4    A systematic review was adopted to assess and ...  ...           NaN
# ..                                                 ...  ...           ...
# 128  The research methodology of this study has two...  ...           NaN
# 129  LCA is an important worldwide environmental ma...  ...           NaN
# 130  LCA is an established method for assessing a w...  ...           NaN
# 131  The large office prototype building developed ...  ...           NaN
# 132  Researchers and practitioners have recognized ...  ...           NaN
#
#     section16 sectionData16 section17 sectionData17 section18 sectionData18  \
# 0         NaN           NaN       NaN           NaN       NaN           NaN
# 1         NaN           NaN       NaN           NaN       NaN           NaN
# 2         NaN           NaN       NaN           NaN       NaN           NaN
# 3         NaN           NaN       NaN           NaN       NaN           NaN
# 4         NaN           NaN       NaN           NaN       NaN           NaN
# ..        ...           ...       ...           ...       ...           ...
# 128       NaN           NaN       NaN           NaN       NaN           NaN
# 129       NaN           NaN       NaN           NaN       NaN           NaN
# 130       NaN           NaN       NaN           NaN       NaN           NaN
# 131       NaN           NaN       NaN           NaN       NaN           NaN
# 132       NaN           NaN       NaN           NaN       NaN           NaN
#
#     section19 sectionData19 journalName
# 0         NaN           NaN      271434
# 1         NaN           NaN      271434
# 2         NaN           NaN      271434
# 3         NaN           NaN      271434
# 4         NaN           NaN      271434
# ..        ...           ...         ...
# 128       NaN           NaN      271434
# 129       NaN           NaN      271434
# 130       NaN           NaN      271434
# 131       NaN           NaN      271434
# 132       NaN           NaN      271434
#
# [133 rows x 45 columns]

# %%
df1 = df
df['journalName'] = str(idNo)
fileSave = 'kgRawData/SD/sd-kg'+idNo+'.csv'
df.to_csv(fileSave)

# %%
idNo = '271434'

import pandas as pd
# filePath = 
data = pd.read_csv('kgRawData/SD/sd-kg' + idNo + '.csv')
data['presence'] = False

searchTerm1 = ['BIM' , 'Building Information Modelling','Building information model','6D BIM', 'Digital construction','Smart construction','Digital engineering']
searchTerm2 = ['Green Building' , 'Green Buildings','Sustainable building','Sustainable buildings','Environmentally friendly design' , 'Sustainability' , 'Sustainable development' , 'Energy','Water' ,'Waste' , 'Thermal comfort','Electricity' ,'Solar','Wind power' , 'Green infrastructure','Life cycle assessment']

validEntries = []

for i in range(data.shape[0]):    
    for st1 in searchTerm1:
        for st2 in searchTerm2:
            if (st1 in data['sectionData0'][i]) and (st2 in data['sectionData0'][i]):
                data['presence'][i] = True
                validEntries.append(i)

uniqueValidEntries = list(set(validEntries))

uniqueDf = pd.DataFrame()
uniqueDf.to_csv('blankFile.csv')

columnNames = ['searchTerm1','searchTerm2','url','Title']

uniqueDf = pd.read_csv("blankFile.csv", names= columnNames , header = None)
uniqueDf = uniqueDf.iloc[1:]

for i in range(20):
    section = "section" + str(i)
    sectionData = "sectionData" + str(i)
    uniqueDf[section] = ''
    uniqueDf[sectionData] = ''
    
for entry in range(len(uniqueValidEntries)):
    uniqueDf.loc[entry] = data.loc[uniqueValidEntries[entry]]    
    

uniqueDf.to_csv('kgRawData/SD/cleanSd-kg'+ idNo + '.csv')

print(len(uniqueDf))
# Out:
# <ipython-input-1-b6aa6908d30f>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['presence'][i] = True
# 29

# %%
uniqueDf
# Out:
#                            searchTerm1                searchTerm2  \
# 0       Building%20information%20model  Life%20cycle%20assessment
# 1                                  BIM     Sustainable%20building
# 2                                  BIM    Sustainable%20buildings
# 3                                  BIM             Sustainability
# 4                                  BIM             Sustainability
# 5                                  BIM                     Energy
# 6                                  BIM                      Waste
# 7                                  BIM                Electricity
# 8                                  BIM  Life%20cycle%20assessment
# 9                                  BIM  Life%20cycle%20assessment
# 10  Building%20Information%20Modelling     Sustainable%20building
# 11  Building%20Information%20Modelling    Sustainable%20buildings
# 12  Building%20Information%20Modelling             Sustainability
# 13  Building%20Information%20Modelling             Sustainability
# 14  Building%20Information%20Modelling             Sustainability
# 15  Building%20Information%20Modelling                     Energy
# 16  Building%20Information%20Modelling                      Waste
# 17  Building%20Information%20Modelling                Electricity
# 18  Building%20Information%20Modelling  Life%20cycle%20assessment
# 19  Building%20Information%20Modelling  Life%20cycle%20assessment
# 20      Building%20information%20model     Sustainable%20building
# 21      Building%20information%20model    Sustainable%20buildings
# 22      Building%20information%20model             Sustainability
# 23      Building%20information%20model             Sustainability
# 24      Building%20information%20model             Sustainability
# 25      Building%20information%20model                     Energy
# 26      Building%20information%20model                      Waste
# 27      Building%20information%20model                Electricity
# 28      Building%20information%20model  Life%20cycle%20assessment
#
#                                                   url  \
# 0   https://www.sciencedirect.com//science/article...
# 1   https://www.sciencedirect.com//science/article...
# 2   https://www.sciencedirect.com//science/article...
# 3   https://www.sciencedirect.com//science/article...
# 4   https://www.sciencedirect.com//science/article...
# 5   https://www.sciencedirect.com//science/article...
# 6   https://www.sciencedirect.com//science/article...
# 7   https://www.sciencedirect.com//science/article...
# 8   https://www.sciencedirect.com//science/article...
# 9   https://www.sciencedirect.com//science/article...
# 10  https://www.sciencedirect.com//science/article...
# 11  https://www.sciencedirect.com//science/article...
# 12  https://www.sciencedirect.com//science/article...
# 13  https://www.sciencedirect.com//science/article...
# 14  https://www.sciencedirect.com//science/article...
# 15  https://www.sciencedirect.com//science/article...
# 16  https://www.sciencedirect.com//science/article...
# 17  https://www.sciencedirect.com//science/article...
# 18  https://www.sciencedirect.com//science/article...
# 19  https://www.sciencedirect.com//science/article...
# 20  https://www.sciencedirect.com//science/article...
# 21  https://www.sciencedirect.com//science/article...
# 22  https://www.sciencedirect.com//science/article...
# 23  https://www.sciencedirect.com//science/article...
# 24  https://www.sciencedirect.com//science/article...
# 25  https://www.sciencedirect.com//science/article...
# 26  https://www.sciencedirect.com//science/article...
# 27  https://www.sciencedirect.com//science/article...
# 28  https://www.sciencedirect.com//science/article...
#
#                                                 Title  section0  \
# 0   BIM-DLCA: An integrated dynamic environmental ...  Abstract
# 1   Sustainable material choice for construction p...  Abstract
# 2   Sustainable material choice for construction p...  Abstract
# 3   Implementing Life Cycle Sustainability Assessm...  Abstract
# 4   Sustainable material choice for construction p...  Abstract
# 5   A holistic framework to utilize natural ventil...  Abstract
# 6   Implementing Life Cycle Sustainability Assessm...  Abstract
# 7   A holistic framework to utilize natural ventil...  Abstract
# 8   BIM-DLCA: An integrated dynamic environmental ...  Abstract
# 9   Implementing Life Cycle Sustainability Assessm...  Abstract
# 10  Sustainable material choice for construction p...  Abstract
# 11  Sustainable material choice for construction p...  Abstract
# 12  Implementing Life Cycle Sustainability Assessm...  Abstract
# 13  Sustainable material choice for construction p...  Abstract
# 14  Sustainability framework for buildings via dat...  Abstract
# 15  A holistic framework to utilize natural ventil...  Abstract
# 16  Implementing Life Cycle Sustainability Assessm...  Abstract
# 17  A holistic framework to utilize natural ventil...  Abstract
# 18  Implementing Life Cycle Sustainability Assessm...  Abstract
# 19  BIM-DLCA: An integrated dynamic environmental ...  Abstract
# 20  Sustainable material choice for construction p...  Abstract
# 21  Sustainable material choice for construction p...  Abstract
# 22  Implementing Life Cycle Sustainability Assessm...  Abstract
# 23  Sustainable material choice for construction p...  Abstract
# 24  Sustainability framework for buildings via dat...  Abstract
# 25  A holistic framework to utilize natural ventil...  Abstract
# 26  Implementing Life Cycle Sustainability Assessm...  Abstract
# 27  A holistic framework to utilize natural ventil...  Abstract
# 28  Implementing Life Cycle Sustainability Assessm...  Abstract
#
#                                          sectionData0  \
# 0   Life cycle assessment (LCA) is an important an...
# 1   Construction professionals and researchers are...
# 2   Construction professionals and researchers are...
# 3   The construction sector is a major producer of...
# 4   Construction professionals and researchers are...
# 5   A novel holistic framework was established usi...
# 6   The construction sector is a major producer of...
# 7   A novel holistic framework was established usi...
# 8   Life cycle assessment (LCA) is an important an...
# 9   The construction sector is a major producer of...
# 10  Construction professionals and researchers are...
# 11  Construction professionals and researchers are...
# 12  The construction sector is a major producer of...
# 13  Construction professionals and researchers are...
# 14  Sustainability is the most important goal to p...
# 15  A novel holistic framework was established usi...
# 16  The construction sector is a major producer of...
# 17  A novel holistic framework was established usi...
# 18  The construction sector is a major producer of...
# 19  Life cycle assessment (LCA) is an important an...
# 20  Construction professionals and researchers are...
# 21  Construction professionals and researchers are...
# 22  The construction sector is a major producer of...
# 23  Construction professionals and researchers are...
# 24  Sustainability is the most important goal to p...
# 25  A novel holistic framework was established usi...
# 26  The construction sector is a major producer of...
# 27  A novel holistic framework was established usi...
# 28  The construction sector is a major producer of...
#
#                         section1  \
# 0                1. Introduction
# 1                1. Introduction
# 2                1. Introduction
# 3                1. Introduction
# 4                1. Introduction
# 5                1. Introduction
# 6                1. Introduction
# 7                1. Introduction
# 8                1. Introduction
# 9                1. Introduction
# 10               1. Introduction
# 11               1. Introduction
# 12               1. Introduction
# 13               1. Introduction
# 14  1. Introduction & background
# 15               1. Introduction
# 16               1. Introduction
# 17               1. Introduction
# 18               1. Introduction
# 19               1. Introduction
# 20               1. Introduction
# 21               1. Introduction
# 22               1. Introduction
# 23               1. Introduction
# 24  1. Introduction & background
# 25               1. Introduction
# 26               1. Introduction
# 27               1. Introduction
# 28               1. Introduction
#
#                                          sectionData1  \
# 0   Human activities have increased carbon emissio...
# 1   The construction industry is responsible for t...
# 2   The construction industry is responsible for t...
# 3   The construction sector is one of the major re...
# 4   The construction industry is responsible for t...
# 5   Mountains cover about 60% of the terrain in Ho...
# 6   The construction sector is one of the major re...
# 7   Mountains cover about 60% of the terrain in Ho...
# 8   Human activities have increased carbon emissio...
# 9   The construction sector is one of the major re...
# 10  The construction industry is responsible for t...
# 11  The construction industry is responsible for t...
# 12  The construction sector is one of the major re...
# 13  The construction industry is responsible for t...
# 14  Sustainability of all human activities and env...
# 15  Mountains cover about 60% of the terrain in Ho...
# 16  The construction sector is one of the major re...
# 17  Mountains cover about 60% of the terrain in Ho...
# 18  The construction sector is one of the major re...
# 19  Human activities have increased carbon emissio...
# 20  The construction industry is responsible for t...
# 21  The construction industry is responsible for t...
# 22  The construction sector is one of the major re...
# 23  The construction industry is responsible for t...
# 24  Sustainability of all human activities and env...
# 25  Mountains cover about 60% of the terrain in Ho...
# 26  The construction sector is one of the major re...
# 27  Mountains cover about 60% of the terrain in Ho...
# 28  The construction sector is one of the major re...
#
#                                   section2  \
# 0                           2. Methodology
# 1                     2. Literature review
# 2                     2. Literature review
# 3                 2. Materials and methods
# 4                     2. Literature review
# 5                           2. Methodology
# 6                 2. Materials and methods
# 7                           2. Methodology
# 8                           2. Methodology
# 9                 2. Materials and methods
# 10                    2. Literature review
# 11                    2. Literature review
# 12                2. Materials and methods
# 13                    2. Literature review
# 14  2. Framework for sustainability metric
# 15                          2. Methodology
# 16                2. Materials and methods
# 17                          2. Methodology
# 18                2. Materials and methods
# 19                          2. Methodology
# 20                    2. Literature review
# 21                    2. Literature review
# 22                2. Materials and methods
# 23                    2. Literature review
# 24  2. Framework for sustainability metric
# 25                          2. Methodology
# 26                2. Materials and methods
# 27                          2. Methodology
# 28                2. Materials and methods
#
#                                          sectionData2  ... section15  \
# 0   LCA is an important worldwide environmental ma...  ...       NaN
# 1   A literature review of the proposed methodolog...  ...       NaN
# 2   A literature review of the proposed methodolog...  ...       NaN
# 3   The research began with a SLR (Section 3) to a...  ...       NaN
# 4   A literature review of the proposed methodolog...  ...       NaN
# 5   Fig. 1 presents the BIM-based framework for es...  ...       NaN
# 6   The research began with a SLR (Section 3) to a...  ...       NaN
# 7   Fig. 1 presents the BIM-based framework for es...  ...       NaN
# 8   LCA is an important worldwide environmental ma...  ...       NaN
# 9   The research began with a SLR (Section 3) to a...  ...       NaN
# 10  A literature review of the proposed methodolog...  ...       NaN
# 11  A literature review of the proposed methodolog...  ...       NaN
# 12  The research began with a SLR (Section 3) to a...  ...       NaN
# 13  A literature review of the proposed methodolog...  ...       NaN
# 14  The proposed framework for the sustainability ...  ...       NaN
# 15  Fig. 1 presents the BIM-based framework for es...  ...       NaN
# 16  The research began with a SLR (Section 3) to a...  ...       NaN
# 17  Fig. 1 presents the BIM-based framework for es...  ...       NaN
# 18  The research began with a SLR (Section 3) to a...  ...       NaN
# 19  LCA is an important worldwide environmental ma...  ...       NaN
# 20  A literature review of the proposed methodolog...  ...       NaN
# 21  A literature review of the proposed methodolog...  ...       NaN
# 22  The research began with a SLR (Section 3) to a...  ...       NaN
# 23  A literature review of the proposed methodolog...  ...       NaN
# 24  The proposed framework for the sustainability ...  ...       NaN
# 25  Fig. 1 presents the BIM-based framework for es...  ...       NaN
# 26  The research began with a SLR (Section 3) to a...  ...       NaN
# 27  Fig. 1 presents the BIM-based framework for es...  ...       NaN
# 28  The research began with a SLR (Section 3) to a...  ...       NaN
#
#    sectionData15 section16 sectionData16 section17 sectionData17 section18  \
# 0            NaN       NaN           NaN       NaN           NaN       NaN
# 1            NaN       NaN           NaN       NaN           NaN       NaN
# 2            NaN       NaN           NaN       NaN           NaN       NaN
# 3            NaN       NaN           NaN       NaN           NaN       NaN
# 4            NaN       NaN           NaN       NaN           NaN       NaN
# 5            NaN       NaN           NaN       NaN           NaN       NaN
# 6            NaN       NaN           NaN       NaN           NaN       NaN
# 7            NaN       NaN           NaN       NaN           NaN       NaN
# 8            NaN       NaN           NaN       NaN           NaN       NaN
# 9            NaN       NaN           NaN       NaN           NaN       NaN
# 10           NaN       NaN           NaN       NaN           NaN       NaN
# 11           NaN       NaN           NaN       NaN           NaN       NaN
# 12           NaN       NaN           NaN       NaN           NaN       NaN
# 13           NaN       NaN           NaN       NaN           NaN       NaN
# 14           NaN       NaN           NaN       NaN           NaN       NaN
# 15           NaN       NaN           NaN       NaN           NaN       NaN
# 16           NaN       NaN           NaN       NaN           NaN       NaN
# 17           NaN       NaN           NaN       NaN           NaN       NaN
# 18           NaN       NaN           NaN       NaN           NaN       NaN
# 19           NaN       NaN           NaN       NaN           NaN       NaN
# 20           NaN       NaN           NaN       NaN           NaN       NaN
# 21           NaN       NaN           NaN       NaN           NaN       NaN
# 22           NaN       NaN           NaN       NaN           NaN       NaN
# 23           NaN       NaN           NaN       NaN           NaN       NaN
# 24           NaN       NaN           NaN       NaN           NaN       NaN
# 25           NaN       NaN           NaN       NaN           NaN       NaN
# 26           NaN       NaN           NaN       NaN           NaN       NaN
# 27           NaN       NaN           NaN       NaN           NaN       NaN
# 28           NaN       NaN           NaN       NaN           NaN       NaN
#
#    sectionData18 section19 sectionData19
# 0            NaN       NaN           NaN
# 1            NaN       NaN           NaN
# 2            NaN       NaN           NaN
# 3            NaN       NaN           NaN
# 4            NaN       NaN           NaN
# 5            NaN       NaN           NaN
# 6            NaN       NaN           NaN
# 7            NaN       NaN           NaN
# 8            NaN       NaN           NaN
# 9            NaN       NaN           NaN
# 10           NaN       NaN           NaN
# 11           NaN       NaN           NaN
# 12           NaN       NaN           NaN
# 13           NaN       NaN           NaN
# 14           NaN       NaN           NaN
# 15           NaN       NaN           NaN
# 16           NaN       NaN           NaN
# 17           NaN       NaN           NaN
# 18           NaN       NaN           NaN
# 19           NaN       NaN           NaN
# 20           NaN       NaN           NaN
# 21           NaN       NaN           NaN
# 22           NaN       NaN           NaN
# 23           NaN       NaN           NaN
# 24           NaN       NaN           NaN
# 25           NaN       NaN           NaN
# 26           NaN       NaN           NaN
# 27           NaN       NaN           NaN
# 28           NaN       NaN           NaN
#
# [29 rows x 44 columns]
