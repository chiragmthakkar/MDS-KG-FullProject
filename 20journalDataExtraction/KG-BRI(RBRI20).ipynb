# %% [markdown]
# BRI

# %%
# Needs Uni enviornment

# %%
import requests
from bs4 import BeautifulSoup
from pandas.io.html import read_html
import pandas as pd

# %%
journal = 'rbri20'

# %%
df = pd.DataFrame()
df.to_csv('blankFile.csv')

columnNames = ['searchTerm1','searchTerm2','url','Title']

df = pd.read_csv("blankFile.csv", names= columnNames , header = None)
df = df.iloc[1:]

for i in range(20):
    section = "section" + str(i)
    sectionData = "sectionData" + str(i)
    df[section] = ''
    df[sectionData] = ''

df
# Out:
# Empty DataFrame
# Columns: [searchTerm1, searchTerm2, url, Title, section0, sectionData0, section1, sectionData1, section2, sectionData2, section3, sectionData3, section4, sectionData4, section5, sectionData5, section6, sectionData6, section7, sectionData7, section8, sectionData8, section9, sectionData9, section10, sectionData10, section11, sectionData11, section12, sectionData12, section13, sectionData13, section14, sectionData14, section15, sectionData15, section16, sectionData16, section17, sectionData17, section18, sectionData18, section19, sectionData19]
# Index: []
#
# [0 rows x 44 columns]

# %%
# searchTerm1 = ['BIM', 'Building Information Modelling']
# searchTerm2 = ['Green Building', 'Green Buildings']

# searchTerm1 = ['a']
# searchTerm2 = ['the']

tc = 0
noResultsList = []

searchTerm1 = ['BIM' , 'Building Information Modelling','Building information model','6D BIM', 'Digital construction','Smart construction','Digital engineering']
searchTerm2 = ['Green Building' , 'Green Buildings','Sustainable building','Sustainable buildings','Environmentally friendly design' , 'Sustainability' , 'Sustainable development' , 'Energy','Water' ,'Waste' , 'Thermal comfort','Electricity' ,'Solar','Wind power' , 'Green infrastructure','Life cycle assessment']

counter = 0
programSearchTerms1 = []
programSearchTerms2 = []

for term2 in searchTerm2:
    text2 = ""
    terms2 = term2.split(' ')
    for t2 in terms2:
        text2 = text2 + t2 + "+"

    fileIndex = text2.rfind("+")
    te = text2[:fileIndex]
    programSearchTerms2.append(te)

print(programSearchTerms2)

for term1 in searchTerm1:
    text1 = ""
    terms1 = term1.split(' ')
    for t2 in terms1:
        text1 = text1 + t2 + "+"

    fileIndex = text1.rfind("+")
    te = text1[:fileIndex]
    programSearchTerms1.append(te)

print(programSearchTerms1)

baseUrl = 'https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22'
querySet = []
row = 0
for item1 in programSearchTerms1:
    for item2 in programSearchTerms2:
        query = baseUrl + item1 +"%22+AND+%22"+ item2+"%22&Ppub=&startPage=&SeriesKey=" + journal
        print(query)
        response = requests.get(query)
        soup = BeautifulSoup(response.text, 'html.parser')
        allParas = soup.find_all("p")
        dd = allParas[0].text
        miniData = dd.split(' ')
        NumberOfResultsStr = miniData[2]
        indexOfcomma = NumberOfResultsStr.find(',')

        if indexOfcomma != -1:
            NumberOfResultsStr = NumberOfResultsStr.replace(',','')

        number = int(NumberOfResultsStr)
        tc = tc + number
                
        page = number // 10
        lastPage = number % 10
        if lastPage > 0:
            page = page + 1

        pageSize = page
#         print(pageSize)

        cnt = 0
        allLinks = []
        
#         for testing purpose only
#         pageSize = 2

        if number == 0:
            noResultsList.append((item1 +","+item2))
            print("No results found")
        else:
            


            print("Extracting all Links")

            for currentPage in range(0,pageSize):
                print("In page: ",currentPage)

                if currentPage != 0:
                    newQuery = query + '&pageSize=10&subjectTitle=&startPage=' + str(currentPage)
                    cnt = cnt + 1
                else:
                    newQuery = query


                print("Searching for query: ",newQuery)
                response = requests.get(newQuery)
                soup = BeautifulSoup(response.text, 'html.parser')
                mydivs = soup.findAll("a", {'class':['ref nowrap']})

                for d in mydivs:
                    url = 'https://www.tandfonline.com' + d.get('href')
                    allLinks.append(url)
    #             print(allLinks)

            print("Extracting data")

            for link in allLinks:
                df.loc[row,'searchTerm1'] = item1
                df.loc[row,'searchTerm2'] = item2
                df.loc[row,'url'] = link
                html_content = requests.get(link).text
                soup = BeautifulSoup(html_content, "lxml")

                for i in soup.find('span',{'class':['NLM_article-title' ,'hlFld-title']}):
    #                 print("Title: ",i)
                    df.loc[row,'Title'] = i

                temp = soup.findAll('h2',{'class':['section-heading-2']} )
                print("Number of sections: ",len(temp))            

                count = 0
                for i in range(len(temp)):

                    if temp[i].text == temp[i].find_next('p').text:

                        extract = "section" + str(count)
                        extractData = temp[i].find_next('p').find_next('p').text
                        df.loc[row,extract] = temp[i].text
                        sectionData = "sectionData" + str(count)                    
                        df.loc[row,sectionData] = extractData
                        count = count + 1
                    else:
                        extract = "section" + str(count)
                        extractData = temp[i].find_next('p').text
                        df.loc[row,extract] = temp[i].text
                        sectionData = "sectionData" + str(count)
                        df.loc[row,sectionData] = extractData
                        count = count + 1


                row = row + 1
                print("row: ",row)
# Out:
# ['Green+Building', 'Green+Buildings', 'Sustainable+building', 'Sustainable+buildings', 'Environmentally+friendly+design', 'Sustainability', 'Sustainable+development', 'Energy', 'Water', 'Waste', 'Thermal+comfort', 'Electricity', 'Solar', 'Wind+power', 'Green+infrastructure', 'Life+cycle+assessment']
# ['BIM', 'Building+Information+Modelling', 'Building+information+model', '6D+BIM', 'Digital+construction', 'Smart+construction', 'Digital+engineering']
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22BIM%22+AND+%22Green+Building%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22BIM%22+AND+%22Green+Buildings%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22BIM%22+AND+%22Sustainable+building%22&Ppub=&startPage=&SeriesKey=rbri20
# Extracting all Links
# In page:  0
# Searching for query:  https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22BIM%22+AND+%22Sustainable+building%22&Ppub=&startPage=&SeriesKey=rbri20
# Extracting data
# Number of sections:  19
# row:  1
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22BIM%22+AND+%22Sustainable+buildings%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22BIM%22+AND+%22Environmentally+friendly+design%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22BIM%22+AND+%22Sustainability%22&Ppub=&startPage=&SeriesKey=rbri20
# Extracting all Links
# In page:  0
# Searching for query:  https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22BIM%22+AND+%22Sustainability%22&Ppub=&startPage=&SeriesKey=rbri20
# Extracting data
# Number of sections:  9
# row:  2
# Number of sections:  19
# row:  3
# Number of sections:  12
# row:  4
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22BIM%22+AND+%22Sustainable+development%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22BIM%22+AND+%22Energy%22&Ppub=&startPage=&SeriesKey=rbri20
# Extracting all Links
# In page:  0
# Searching for query:  https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22BIM%22+AND+%22Energy%22&Ppub=&startPage=&SeriesKey=rbri20
# Extracting data
# Number of sections:  7
# row:  5
# Number of sections:  12
# row:  6
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22BIM%22+AND+%22Water%22&Ppub=&startPage=&SeriesKey=rbri20
# Extracting all Links
# In page:  0
# Searching for query:  https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22BIM%22+AND+%22Water%22&Ppub=&startPage=&SeriesKey=rbri20
# Extracting data
# Number of sections:  9
# row:  7
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22BIM%22+AND+%22Waste%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22BIM%22+AND+%22Thermal+comfort%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22BIM%22+AND+%22Electricity%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22BIM%22+AND+%22Solar%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22BIM%22+AND+%22Wind+power%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22BIM%22+AND+%22Green+infrastructure%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22BIM%22+AND+%22Life+cycle+assessment%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Building+Information+Modelling%22+AND+%22Green+Building%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Building+Information+Modelling%22+AND+%22Green+Buildings%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Building+Information+Modelling%22+AND+%22Sustainable+building%22&Ppub=&startPage=&SeriesKey=rbri20
# Extracting all Links
# In page:  0
# Searching for query:  https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Building+Information+Modelling%22+AND+%22Sustainable+building%22&Ppub=&startPage=&SeriesKey=rbri20
# Extracting data
# Number of sections:  19
# row:  8
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Building+Information+Modelling%22+AND+%22Sustainable+buildings%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Building+Information+Modelling%22+AND+%22Environmentally+friendly+design%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Building+Information+Modelling%22+AND+%22Sustainability%22&Ppub=&startPage=&SeriesKey=rbri20
# Extracting all Links
# In page:  0
# Searching for query:  https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Building+Information+Modelling%22+AND+%22Sustainability%22&Ppub=&startPage=&SeriesKey=rbri20
# Extracting data
# Number of sections:  9
# row:  9
# Number of sections:  19
# row:  10
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Building+Information+Modelling%22+AND+%22Sustainable+development%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Building+Information+Modelling%22+AND+%22Energy%22&Ppub=&startPage=&SeriesKey=rbri20
# Extracting all Links
# In page:  0
# Searching for query:  https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Building+Information+Modelling%22+AND+%22Energy%22&Ppub=&startPage=&SeriesKey=rbri20
# Extracting data
# Number of sections:  7
# row:  11
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Building+Information+Modelling%22+AND+%22Water%22&Ppub=&startPage=&SeriesKey=rbri20
# Extracting all Links
# In page:  0
# Searching for query:  https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Building+Information+Modelling%22+AND+%22Water%22&Ppub=&startPage=&SeriesKey=rbri20
# Extracting data
# Number of sections:  9
# row:  12
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Building+Information+Modelling%22+AND+%22Waste%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Building+Information+Modelling%22+AND+%22Thermal+comfort%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Building+Information+Modelling%22+AND+%22Electricity%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Building+Information+Modelling%22+AND+%22Solar%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Building+Information+Modelling%22+AND+%22Wind+power%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Building+Information+Modelling%22+AND+%22Green+infrastructure%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Building+Information+Modelling%22+AND+%22Life+cycle+assessment%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Building+information+model%22+AND+%22Green+Building%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Building+information+model%22+AND+%22Green+Buildings%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Building+information+model%22+AND+%22Sustainable+building%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Building+information+model%22+AND+%22Sustainable+buildings%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Building+information+model%22+AND+%22Environmentally+friendly+design%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Building+information+model%22+AND+%22Sustainability%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Building+information+model%22+AND+%22Sustainable+development%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Building+information+model%22+AND+%22Energy%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Building+information+model%22+AND+%22Water%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Building+information+model%22+AND+%22Waste%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Building+information+model%22+AND+%22Thermal+comfort%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Building+information+model%22+AND+%22Electricity%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Building+information+model%22+AND+%22Solar%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Building+information+model%22+AND+%22Wind+power%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Building+information+model%22+AND+%22Green+infrastructure%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Building+information+model%22+AND+%22Life+cycle+assessment%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%226D+BIM%22+AND+%22Green+Building%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%226D+BIM%22+AND+%22Green+Buildings%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%226D+BIM%22+AND+%22Sustainable+building%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%226D+BIM%22+AND+%22Sustainable+buildings%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%226D+BIM%22+AND+%22Environmentally+friendly+design%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%226D+BIM%22+AND+%22Sustainability%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%226D+BIM%22+AND+%22Sustainable+development%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%226D+BIM%22+AND+%22Energy%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%226D+BIM%22+AND+%22Water%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%226D+BIM%22+AND+%22Waste%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%226D+BIM%22+AND+%22Thermal+comfort%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%226D+BIM%22+AND+%22Electricity%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%226D+BIM%22+AND+%22Solar%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%226D+BIM%22+AND+%22Wind+power%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%226D+BIM%22+AND+%22Green+infrastructure%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%226D+BIM%22+AND+%22Life+cycle+assessment%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Digital+construction%22+AND+%22Green+Building%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Digital+construction%22+AND+%22Green+Buildings%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Digital+construction%22+AND+%22Sustainable+building%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Digital+construction%22+AND+%22Sustainable+buildings%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Digital+construction%22+AND+%22Environmentally+friendly+design%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Digital+construction%22+AND+%22Sustainability%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Digital+construction%22+AND+%22Sustainable+development%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Digital+construction%22+AND+%22Energy%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Digital+construction%22+AND+%22Water%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Digital+construction%22+AND+%22Waste%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Digital+construction%22+AND+%22Thermal+comfort%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Digital+construction%22+AND+%22Electricity%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Digital+construction%22+AND+%22Solar%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Digital+construction%22+AND+%22Wind+power%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Digital+construction%22+AND+%22Green+infrastructure%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Digital+construction%22+AND+%22Life+cycle+assessment%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Smart+construction%22+AND+%22Green+Building%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Smart+construction%22+AND+%22Green+Buildings%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Smart+construction%22+AND+%22Sustainable+building%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Smart+construction%22+AND+%22Sustainable+buildings%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Smart+construction%22+AND+%22Environmentally+friendly+design%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Smart+construction%22+AND+%22Sustainability%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Smart+construction%22+AND+%22Sustainable+development%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Smart+construction%22+AND+%22Energy%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Smart+construction%22+AND+%22Water%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Smart+construction%22+AND+%22Waste%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Smart+construction%22+AND+%22Thermal+comfort%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Smart+construction%22+AND+%22Electricity%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Smart+construction%22+AND+%22Solar%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Smart+construction%22+AND+%22Wind+power%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Smart+construction%22+AND+%22Green+infrastructure%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Smart+construction%22+AND+%22Life+cycle+assessment%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Digital+engineering%22+AND+%22Green+Building%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Digital+engineering%22+AND+%22Green+Buildings%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Digital+engineering%22+AND+%22Sustainable+building%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Digital+engineering%22+AND+%22Sustainable+buildings%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Digital+engineering%22+AND+%22Environmentally+friendly+design%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Digital+engineering%22+AND+%22Sustainability%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Digital+engineering%22+AND+%22Sustainable+development%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Digital+engineering%22+AND+%22Energy%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Digital+engineering%22+AND+%22Water%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Digital+engineering%22+AND+%22Waste%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Digital+engineering%22+AND+%22Thermal+comfort%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Digital+engineering%22+AND+%22Electricity%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Digital+engineering%22+AND+%22Solar%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Digital+engineering%22+AND+%22Wind+power%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Digital+engineering%22+AND+%22Green+infrastructure%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found
# https://www.tandfonline.com/action/doSearch?field1=Abstract&text1=%22Digital+engineering%22+AND+%22Life+cycle+assessment%22&Ppub=&startPage=&SeriesKey=rbri20
# No results found

# %%
noResultsList
# Out:
# ['BIM,Green+Building',
#  'BIM,Green+Buildings',
#  'BIM,Sustainable+buildings',
#  'BIM,Environmentally+friendly+design',
#  'BIM,Sustainable+development',
#  'BIM,Waste',
#  'BIM,Thermal+comfort',
#  'BIM,Electricity',
#  'BIM,Solar',
#  'BIM,Wind+power',
#  'BIM,Green+infrastructure',
#  'BIM,Life+cycle+assessment',
#  'Building+Information+Modelling,Green+Building',
#  'Building+Information+Modelling,Green+Buildings',
#  'Building+Information+Modelling,Sustainable+buildings',
#  'Building+Information+Modelling,Environmentally+friendly+design',
#  'Building+Information+Modelling,Sustainable+development',
#  'Building+Information+Modelling,Waste',
#  'Building+Information+Modelling,Thermal+comfort',
#  'Building+Information+Modelling,Electricity',
#  'Building+Information+Modelling,Solar',
#  'Building+Information+Modelling,Wind+power',
#  'Building+Information+Modelling,Green+infrastructure',
#  'Building+Information+Modelling,Life+cycle+assessment',
#  'Building+information+model,Green+Building',
#  'Building+information+model,Green+Buildings',
#  'Building+information+model,Sustainable+building',
#  'Building+information+model,Sustainable+buildings',
#  'Building+information+model,Environmentally+friendly+design',
#  'Building+information+model,Sustainability',
#  'Building+information+model,Sustainable+development',
#  'Building+information+model,Energy',
#  'Building+information+model,Water',
#  'Building+information+model,Waste',
#  'Building+information+model,Thermal+comfort',
#  'Building+information+model,Electricity',
#  'Building+information+model,Solar',
#  'Building+information+model,Wind+power',
#  'Building+information+model,Green+infrastructure',
#  'Building+information+model,Life+cycle+assessment',
#  '6D+BIM,Green+Building',
#  '6D+BIM,Green+Buildings',
#  '6D+BIM,Sustainable+building',
#  '6D+BIM,Sustainable+buildings',
#  '6D+BIM,Environmentally+friendly+design',
#  '6D+BIM,Sustainability',
#  '6D+BIM,Sustainable+development',
#  '6D+BIM,Energy',
#  '6D+BIM,Water',
#  '6D+BIM,Waste',
#  '6D+BIM,Thermal+comfort',
#  '6D+BIM,Electricity',
#  '6D+BIM,Solar',
#  '6D+BIM,Wind+power',
#  '6D+BIM,Green+infrastructure',
#  '6D+BIM,Life+cycle+assessment',
#  'Digital+construction,Green+Building',
#  'Digital+construction,Green+Buildings',
#  'Digital+construction,Sustainable+building',
#  'Digital+construction,Sustainable+buildings',
#  'Digital+construction,Environmentally+friendly+design',
#  'Digital+construction,Sustainability',
#  'Digital+construction,Sustainable+development',
#  'Digital+construction,Energy',
#  'Digital+construction,Water',
#  'Digital+construction,Waste',
#  'Digital+construction,Thermal+comfort',
#  'Digital+construction,Electricity',
#  'Digital+construction,Solar',
#  'Digital+construction,Wind+power',
#  'Digital+construction,Green+infrastructure',
#  'Digital+construction,Life+cycle+assessment',
#  'Smart+construction,Green+Building',
#  'Smart+construction,Green+Buildings',
#  'Smart+construction,Sustainable+building',
#  'Smart+construction,Sustainable+buildings',
#  'Smart+construction,Environmentally+friendly+design',
#  'Smart+construction,Sustainability',
#  'Smart+construction,Sustainable+development',
#  'Smart+construction,Energy',
#  'Smart+construction,Water',
#  'Smart+construction,Waste',
#  'Smart+construction,Thermal+comfort',
#  'Smart+construction,Electricity',
#  'Smart+construction,Solar',
#  'Smart+construction,Wind+power',
#  'Smart+construction,Green+infrastructure',
#  'Smart+construction,Life+cycle+assessment',
#  'Digital+engineering,Green+Building',
#  'Digital+engineering,Green+Buildings',
#  'Digital+engineering,Sustainable+building',
#  'Digital+engineering,Sustainable+buildings',
#  'Digital+engineering,Environmentally+friendly+design',
#  'Digital+engineering,Sustainability',
#  'Digital+engineering,Sustainable+development',
#  'Digital+engineering,Energy',
#  'Digital+engineering,Water',
#  'Digital+engineering,Waste',
#  'Digital+engineering,Thermal+comfort',
#  'Digital+engineering,Electricity',
#  'Digital+engineering,Solar',
#  'Digital+engineering,Wind+power',
#  'Digital+engineering,Green+infrastructure',
#  'Digital+engineering,Life+cycle+assessment']

# %%
df['journalName'] = journal

# %%
df
# Out:
#                        searchTerm1           searchTerm2  \
# 0                              BIM  Sustainable+building
# 1                              BIM        Sustainability
# 2                              BIM        Sustainability
# 3                              BIM        Sustainability
# 4                              BIM                Energy
# 5                              BIM                Energy
# 6                              BIM                 Water
# 7   Building+Information+Modelling  Sustainable+building
# 8   Building+Information+Modelling        Sustainability
# 9   Building+Information+Modelling        Sustainability
# 10  Building+Information+Modelling                Energy
# 11  Building+Information+Modelling                 Water
#
#                                                   url  \
# 0   https://www.tandfonline.com/doi/full/10.1080/0...
# 1   https://www.tandfonline.com/doi/full/10.1080/0...
# 2   https://www.tandfonline.com/doi/full/10.1080/0...
# 3   https://www.tandfonline.com/doi/full/10.1080/0...
# 4   https://www.tandfonline.com/doi/full/10.1080/0...
# 5   https://www.tandfonline.com/doi/full/10.1080/0...
# 6   https://www.tandfonline.com/doi/full/10.1080/0...
# 7   https://www.tandfonline.com/doi/full/10.1080/0...
# 8   https://www.tandfonline.com/doi/full/10.1080/0...
# 9   https://www.tandfonline.com/doi/full/10.1080/0...
# 10  https://www.tandfonline.com/doi/full/10.1080/0...
# 11  https://www.tandfonline.com/doi/full/10.1080/0...
#
#                                                 Title  \
# 0   From the design of green buildings to resilien...
# 1   Building information modelling application of ...
# 2   From the design of green buildings to resilien...
# 3    emissions assessment tools: a case study in w...
# 4   Quantifying the impact of building envelope co...
# 5    emissions assessment tools: a case study in w...
# 6   Building information modelling application of ...
# 7   From the design of green buildings to resilien...
# 8   Building information modelling application of ...
# 9   From the design of green buildings to resilien...
# 10  Quantifying the impact of building envelope co...
# 11  Building information modelling application of ...
#
#                                              section0  \
# 0                                            ABSTRACT
# 1   ABSTRACTFormulae display:?Mathematical formula...
# 2                                            ABSTRACT
# 3   ABSTRACTFormulae display:?Mathematical formula...
# 4                                            ABSTRACT
# 5   ABSTRACTFormulae display:?Mathematical formula...
# 6   ABSTRACTFormulae display:?Mathematical formula...
# 7                                            ABSTRACT
# 8   ABSTRACTFormulae display:?Mathematical formula...
# 9                                            ABSTRACT
# 10                                           ABSTRACT
# 11  ABSTRACTFormulae display:?Mathematical formula...
#
#                                          sectionData0  \
# 0   The green and the subsequent sustainable build...
# 1                                            ABSTRACT
# 2   The green and the subsequent sustainable build...
# 3                                            ABSTRACT
# 4   The gap between the architectural information ...
# 5                                            ABSTRACT
# 6                                            ABSTRACT
# 7   The green and the subsequent sustainable build...
# 8                                            ABSTRACT
# 9   The green and the subsequent sustainable build...
# 10  The gap between the architectural information ...
# 11                                           ABSTRACT
#
#                             section1  \
# 0   Scope of environmental knowledge
# 1                       Introduction
# 2   Scope of environmental knowledge
# 3                         Highlights
# 4                       Introduction
# 5                         Highlights
# 6                       Introduction
# 7   Scope of environmental knowledge
# 8                       Introduction
# 9   Scope of environmental knowledge
# 10                      Introduction
# 11                      Introduction
#
#                                          sectionData1  \
# 0   In a remarkable contribution ‘Changing context...
# 1   The global material footprint will double by 2...
# 2   In a remarkable contribution ‘Changing context...
# 3
# 4   Building information models contain most of th...
# 5
# 6   The global material footprint will double by 2...
# 7   In a remarkable contribution ‘Changing context...
# 8   The global material footprint will double by 2...
# 9   In a remarkable contribution ‘Changing context...
# 10  Building information models contain most of th...
# 11  The global material footprint will double by 2...
#
#                               section2  \
# 0   Architecture before green building
# 1                Materials and methods
# 2   Architecture before green building
# 3                         Introduction
# 4                              Methods
# 5                         Introduction
# 6                Materials and methods
# 7   Architecture before green building
# 8                Materials and methods
# 9   Architecture before green building
# 10                             Methods
# 11               Materials and methods
#
#                                          sectionData2  ...  \
# 0   For a long time the green building movement an...  ...
# 1   An additional tab in the Autodesk Revit softwa...  ...
# 2   For a long time the green building movement an...  ...
# 3   In 2002, the European Union (EU) published the...  ...
# 4   The impact of uncertainty of the thermo-physic...  ...
# 5   In 2002, the European Union (EU) published the...  ...
# 6   An additional tab in the Autodesk Revit softwa...  ...
# 7   For a long time the green building movement an...  ...
# 8   An additional tab in the Autodesk Revit softwa...  ...
# 9   For a long time the green building movement an...  ...
# 10  The impact of uncertainty of the thermo-physic...  ...
# 11  An additional tab in the Autodesk Revit softwa...  ...
#
#                                         sectionData15    section16  \
# 0   The initial question ‘Why did the green buildi...  Conclusions
# 1                                                 NaN          NaN
# 2   The initial question ‘Why did the green buildi...  Conclusions
# 3                                                 NaN          NaN
# 4                                                 NaN          NaN
# 5                                                 NaN          NaN
# 6                                                 NaN          NaN
# 7   The initial question ‘Why did the green buildi...  Conclusions
# 8                                                 NaN          NaN
# 9   The initial question ‘Why did the green buildi...  Conclusions
# 10                                                NaN          NaN
# 11                                                NaN          NaN
#
#                                         sectionData16             section17  \
# 0   The green building movement and the subsequent...  Disclosure statement
# 1                                                 NaN                   NaN
# 2   The green building movement and the subsequent...  Disclosure statement
# 3                                                 NaN                   NaN
# 4                                                 NaN                   NaN
# 5                                                 NaN                   NaN
# 6                                                 NaN                   NaN
# 7   The green building movement and the subsequent...  Disclosure statement
# 8                                                 NaN                   NaN
# 9   The green building movement and the subsequent...  Disclosure statement
# 10                                                NaN                   NaN
# 11                                                NaN                   NaN
#
#                                         sectionData17 section18  \
# 0   No potential conflict of interest was reported...     ORCID
# 1                                                 NaN       NaN
# 2   No potential conflict of interest was reported...     ORCID
# 3                                                 NaN       NaN
# 4                                                 NaN       NaN
# 5                                                 NaN       NaN
# 6                                                 NaN       NaN
# 7   No potential conflict of interest was reported...     ORCID
# 8                                                 NaN       NaN
# 9   No potential conflict of interest was reported...     ORCID
# 10                                                NaN       NaN
# 11                                                NaN       NaN
#
#                                         sectionData18 section19 sectionData19  \
# 0   Niklaus Kohler http://orcid.org/0000-0002-1861...       NaN           NaN
# 1                                                 NaN       NaN           NaN
# 2   Niklaus Kohler http://orcid.org/0000-0002-1861...       NaN           NaN
# 3                                                 NaN       NaN           NaN
# 4                                                 NaN       NaN           NaN
# 5                                                 NaN       NaN           NaN
# 6                                                 NaN       NaN           NaN
# 7   Niklaus Kohler http://orcid.org/0000-0002-1861...       NaN           NaN
# 8                                                 NaN       NaN           NaN
# 9   Niklaus Kohler http://orcid.org/0000-0002-1861...       NaN           NaN
# 10                                                NaN       NaN           NaN
# 11                                                NaN       NaN           NaN
#
#    journalName
# 0       rbri20
# 1       rbri20
# 2       rbri20
# 3       rbri20
# 4       rbri20
# 5       rbri20
# 6       rbri20
# 7       rbri20
# 8       rbri20
# 9       rbri20
# 10      rbri20
# 11      rbri20
#
# [12 rows x 45 columns]

# %%
jName = 'kgRawData/KG-' + journal +'.csv'
df.to_csv(jName)

# %%
journalName = 'rbri20'

import pandas as pd
df = pd.read_csv('kgRawData/KG-'+ journalName +'.csv')
df = df.where(pd.notnull(df), None)

import re
absRows = []
rowsFound = []
for i in range(len(df['url'])):
    text = df['url'][i]
    pattern = '/abs/'
    if re.search(pattern, text):
        absRows.append(i)
    else:
        rowsFound.append(i)
        
rowsFoundDf = pd.DataFrame()
rowsFoundDf.to_csv('blankFile.csv')

columnNames = ['searchTerm1','searchTerm2','url','Title']

rowsFoundDf = pd.read_csv("blankFile.csv", names= columnNames , header = None)
rowsFoundDf = rowsFoundDf.iloc[1:]

for i in range(20):
    section = "section" + str(i)
    sectionData = "sectionData" + str(i)
    rowsFoundDf[section] = ''
    rowsFoundDf[sectionData] = ''

    
absRowsDf = pd.DataFrame()
absRowsDf.to_csv('blankFile.csv')

columnNames = ['searchTerm1','searchTerm2','url','Title']

absRowsDf = pd.read_csv("blankFile.csv", names= columnNames , header = None)
absRowsDf = absRowsDf.iloc[1:]

for i in range(20):
    section = "section" + str(i)
    sectionData = "sectionData" + str(i)
    absRowsDf[section] = ''
    absRowsDf[sectionData] = ''
    
    
for entry in range(len(rowsFound)):
    rowsFoundDf.loc[entry] = df.loc[rowsFound[entry]]

for entry in range(len(absRows)):
    absRowsDf.loc[entry] = df.loc[absRows[entry]]

rowsFoundDf.to_csv('kgRawData/tandf/kg-'+ journalName +'-full.csv')
absRowsDf.to_csv('kgRawData/tandf/kg-'+ journalName +'-abs.csv')

print(len(absRowsDf))
print(len(rowsFoundDf))
# Out:
# 0
# 12
